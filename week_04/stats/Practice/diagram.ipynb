# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df_cars = pd.read_csv("CarsData.csv")
df = df_cars.head(1500)
# Out:
#               model  year  price transmission  mileage fuelType  tax   mpg  \
# 0               I10  2017   7495       Manual    11630   Petrol  145  60.1
# 1              Polo  2017  10989       Manual     9200   Petrol  145  58.9
# 2          2 Series  2019  27990    Semi-Auto     1614   Diesel  145  49.6
# 3      Yeti Outdoor  2017  12495       Manual    30960   Diesel  150  62.8
# 4            Fiesta  2017   7999       Manual    19353   Petrol  125  54.3
# ...             ...   ...    ...          ...      ...      ...  ...   ...
# 1495             Q3  2020  26890       Manual     2574   Petrol  145  40.9
# 1496          Astra  2017  10790       Manual    34000   Diesel  145  72.4
# 1497       5 Series  2019  26888    Automatic     8070   Diesel  145  65.7
# 1498          Focus  2018  17000       Manual    11587   Diesel  145  67.3
# 1499       5 Series  2015  10499    Automatic    82375   Diesel   20  68.9
#
#       engineSize Manufacturer
# 0            1.0       hyundi
# ...

# %%
sns.histplot(df["price"], kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
df["model"].count()
# Out:
# 97712

# %%
df.count()
# Out:
# model           97712
# year            97712
# price           97712
# transmission    97712
# mileage         97712
# fuelType        97712
# tax             97712
# mpg             97712
# engineSize      97712
# Manufacturer    97712
# dtype: int64

# %%
df.shape
# Out:
# (97712, 10)

# %%
data = df[(df["Manufacturer"] == "BMW") & (df["price"] > 30000)]

# %%
sns.histplot(data["price"])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
plt.plot(data["price"])

# %%
df
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0                I10  2017   7495       Manual    11630   Petrol  145  60.1
# 1               Polo  2017  10989       Manual     9200   Petrol  145  58.9
# 2           2 Series  2019  27990    Semi-Auto     1614   Diesel  145  49.6
# 3       Yeti Outdoor  2017  12495       Manual    30960   Diesel  150  62.8
# 4             Fiesta  2017   7999       Manual    19353   Petrol  125  54.3
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 97707         Fiesta  2017  10447    Automatic     8337   Petrol  145  54.3
# 97708       3 Series  2014  14995       Manual    25372   Diesel   30  61.4
# 97709         Fiesta  2017   8950       Manual    19910   Petrol  125  54.3
# 97710          Astra  2017  10700    Automatic    24468   Petrol  125  50.4
# 97711    Grandland X  2019  15798       Manual    10586   Diesel  150  48.7
#
#        engineSize Manufacturer
# ...

# %%
bmw_2_series = df[(df["Manufacturer"] == "BMW") & (df["model"] == " 2 Series") & (df["price"] > 25000)]
bmw_2_series
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 2       2 Series  2019  27990    Semi-Auto     1614   Diesel  145  49.6
# 241     2 Series  2019  33440    Automatic       10   Diesel  145  64.2
# 532     2 Series  2019  27016    Automatic     1402   Petrol  145  39.8
# 1363    2 Series  2019  25449    Automatic     3890   Diesel  145  48.7
# 2429    2 Series  2019  27995    Semi-Auto     7296   Petrol  145  39.8
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 94932   2 Series  2019  25466    Automatic     6179   Diesel  145  46.3
# 95215   2 Series  2020  28000    Semi-Auto     1501   Diesel  145  65.7
# 95344   2 Series  2019  25490    Semi-Auto     7466   Diesel  145  65.7
# 96365   2 Series  2019  25780    Semi-Auto     2859   Diesel  145  48.7
# 96822   2 Series  2019  25995    Automatic     6500   Diesel  145  46.3
#
#        engineSize Manufacturer
# 2             2.0          BMW
# 241           2.0          BMW
# ...

# %%
sns.scatterplot(bmw_2_series.mileage)
# Out:
# <Axes: ylabel='mileage'>

# %%
sns.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %%
df["Manufacturer"].unique()
# Out:
# array(['hyundi', 'volkswagen', 'BMW', 'skoda', 'ford', 'toyota', 'merc',
#        'vauxhall', 'Audi'], dtype=object)

# %%
bmw = df[df["Manufacturer"] == "BMW"]
vip_bmw = bmw[bmw["price"] > 70000].price
mileage_bmw = bmw[bmw["mileage"] > 120000].mileage
plt.plot(vip_bmw, "o-", color="Purple")
plt.plot(mileage_bmw, "o--", color="red")
plt.xlabel("Cars")
plt.ylabel("Price and Mileage")
plt.show()

# %%
df
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0                I10  2017   7495       Manual    11630   Petrol  145  60.1
# 1               Polo  2017  10989       Manual     9200   Petrol  145  58.9
# 2           2 Series  2019  27990    Semi-Auto     1614   Diesel  145  49.6
# 3       Yeti Outdoor  2017  12495       Manual    30960   Diesel  150  62.8
# 4             Fiesta  2017   7999       Manual    19353   Petrol  125  54.3
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 97707         Fiesta  2017  10447    Automatic     8337   Petrol  145  54.3
# 97708       3 Series  2014  14995       Manual    25372   Diesel   30  61.4
# 97709         Fiesta  2017   8950       Manual    19910   Petrol  125  54.3
# 97710          Astra  2017  10700    Automatic    24468   Petrol  125  50.4
# 97711    Grandland X  2019  15798       Manual    10586   Diesel  150  48.7
#
#        engineSize Manufacturer
# ...

# %%
bmw = df[df["Manufacturer"] == "BMW"].price
bmw
# Out:
# 2        27990
# 11       10550
# 34       19990
# 39        8998
# 43       19799
#          ...
# 97679    13499
# 97680     8990
# 97684    16895
# 97693    10500
# 97708    14995
# Name: price, Length: 10664, dtype: int64

# %%
price_bmw = list(bmw)

# %%
from class_stat import Statictics
stats = Statictics()

mean_price_bmw = stats.mean(price_bmw)
mean_price_bmw
# Out:
# 22692.88869092273

# %%
np.mean(price_bmw)
# Out:
# 22692.88869092273

# %%
sns.histplot(price_bmw, kde=True, bins=300)
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.boxenplot(price_bmw)
sns.stripplot(price_bmw)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  97712.000000   97712.000000   97712.000000  97712.000000  97712.000000
# mean    2017.066502   16773.487555   23219.475499    120.142408     55.205623
# std        2.118661    9868.552222   21060.882301     63.357250     16.181659
# min     1970.000000     450.000000       1.000000      0.000000      0.300000
# 25%     2016.000000    9999.000000    7673.000000    125.000000     47.100000
# 50%     2017.000000   14470.000000   17682.500000    145.000000     54.300000
# 75%     2019.000000   20750.000000   32500.000000    145.000000     62.800000
# max     2024.000000  159999.000000  323000.000000    580.000000    470.800000
#
#          engineSize
# count  97712.000000
# mean       1.664913
# std        0.558574
# min        0.000000
# 25%        1.200000
# 50%        1.600000
# 75%        2.000000
# max        6.600000

# %%
a = df[df["Manufacturer"] == "BMW"].Manufacturer.count()
b = df[df["Manufacturer"] == "ford"].Manufacturer.count()
c = df[df["Manufacturer"] == "hyundi"].Manufacturer.count()
d = df[df["Manufacturer"] == "skoda"].Manufacturer.count()
e = df[df["Manufacturer"] == "Audi"].Manufacturer.count()
f = df[df["Manufacturer"] == "toyota"].Manufacturer.count()
cars = ["BMW", "ford", "hyundi", "skoda", "Audi", "toyota"]
count = [a, b, c, d, e, f]

plt.bar(x=cars, height=count)
plt.show()

# %%
cars = df["Manufacturer"].unique()
print(cars)
# Out:
# ['hyundi' 'volkswagen' 'BMW' 'skoda' 'ford' 'toyota' 'merc' 'vauxhall'
#  'Audi']

# %%
counts = []
for i in cars:
    con = df[df["Manufacturer"] == i].Manufacturer.count()
    counts.append(con)
counts
# Out:
# [4774, 14893, 10664, 6188, 17811, 6699, 12860, 13258, 10565]

# %%
plt.figure(figsize=(8, 6))
plt.bar(x=cars, height=counts, color="purple")
# Out:
# <BarContainer object of 9 artists>

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=cars, y=counts, hue=["red", "purple", "skyblue", "orange", "black", "yellow", "green", "blue", "scarlet"])
plt.xlabel('Cars')
plt.ylabel("Counts")
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.pie(counts, labels=cars, autopct="%.2f%%")
plt.show()
