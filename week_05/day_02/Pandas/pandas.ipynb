# %% [markdown]
# # Pandas
# * Pandas is a open source python library designed specifically for accomplishing data analysis tasks.

# %%
import numpy as np
import pandas as pd

# %%
data = [10, 20, 30, 40, 50]
type(data)
# Out:
# list

# %%
series = pd.Series(data)
print(series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
dict = {
    "name": "Rajendra",
    "age": 23,
    "address": "Bhaktapur"
}

# %%
dict_series = pd.Series(dict)

# %%
type(dict_series)
# Out:
# pandas.core.series.Series

# %%
arr = np.array(data)
arr
# Out:
# array([10, 20, 30, 40, 50])

# %%
arr_series = pd.Series(arr)
arr_series
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int32

# %%
type(arr_series)
# Out:
# pandas.core.series.Series

# %%
arr_series.shape
# Out:
# (5,)

# %% [markdown]
# # DataFrame

# %%
nested_list = [[30, 40, 20], [20, 50, 10], [20, 50, 20]]

# %%
pd.DataFrame(nested_list, columns=["col1", "col2", "col3"])
# Out:
#    col1  col2  col3
# 0    30    40    20
# 1    20    50    10
# 2    20    50    20

# %%
nested_list[1][-1]
# Out:
# 10

# %%
len(nested_list)
# Out:
# 3

# %%
data_dict = {
    "Name": ["Rajendra", "Naresh", "Mohan"],
    "Age": [23, 23, 34]
}

# %%
dict_df = pd.DataFrame(data_dict)

# %%
dict_df
# Out:
#        Name  Age
# 0  Rajendra   23
# 1    Naresh   23
# 2     Mohan   34

# %%
dict_df.columns = ["name", "age"]

# %%
dict_df
# Out:
#        name  age
# 0  Rajendra   23
# 1    Naresh   23
# 2     Mohan   34

# %%
type(dict_df)
# Out:
# pandas.core.frame.DataFrame

# %%
list_dict = [{"name": "Rajendra", "age": 23, "address": "Bhaktapur"}, {"name": "Mohan", "age": 33, "address": "panauti"}, {"name": "Naresh", "address": "Bhaktapur"}]

# %%
pd.DataFrame(list_dict)
# Out:
#        name   age    address
# 0  Rajendra  23.0  Bhaktapur
# 1     Mohan  33.0    panauti
# 2    Naresh   NaN  Bhaktapur

# %%
df = pd.read_csv("car_details.csv")

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
# import openpyxl
# df.to_excel("excel.xlsx", "Sheet1")

# %%
df_hr = pd.read_csv("data/HR_comma_sep.csv")

# %%
df_hr.head() # first five rows
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df_hr.tail() # last five rows
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years Department salary
# 14994                      0    support    low
# 14995                      0    support    low
# 14996                      0    support    low
# ...

# %%
df_hr.shape # shape of DataFrame
# Out:
# (14999, 10)

# %%
df_hr.index # gives total index and step
# Out:
# RangeIndex(start=0, stop=14999, step=1)

# %%
nested_list = [[4, 2, 5], [2, 5, 2]]
pd.DataFrame(nested_list)
# Out:
#    0  1  2
# 0  4  2  5
# 1  2  5  2

# %%
df_hr.columns # gives columns name in list
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
df_hr.dtypes # gives overall datatypes columns data
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# Department                object
# salary                    object
# dtype: object

# %%
hr = df_hr

# %%
hr.rename(columns={"last_evaluation": "le"}, inplace=True)

# %%
hr.head(2)
# Out:
#    satisfaction_level    le  number_project  average_montly_hours  \
# 0                0.38  0.53               2                   157
# 1                0.80  0.86               5                   262
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium

# %%
df_hr.head(2)
# Out:
#    satisfaction_level    le  number_project  average_montly_hours  \
# 0                0.38  0.53               2                   157
# 1                0.80  0.86               5                   262
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium

# %%
df_hr.to_numpy() # convert the data to numpy array
# Out:
# array([[0.38, 0.53, 2, ..., 0, 'sales', 'low'],
#        [0.8, 0.86, 5, ..., 0, 'sales', 'medium'],
#        [0.11, 0.88, 7, ..., 0, 'sales', 'medium'],
#        ...,
#        [0.37, 0.53, 2, ..., 0, 'support', 'low'],
#        [0.11, 0.96, 6, ..., 0, 'support', 'low'],
#        [0.37, 0.52, 2, ..., 0, 'support', 'low']], dtype=object)

# %%
df_hr.info() # gives class, index, columns, datatypes, null, not-null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   le                     14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# * DataFrame occupies 1.1+ MB memory
# * Columns are of types: float64, int64, object
# * Total rows = 14999
# * No any columns contains null values

# %%
df_hr.values # same as .to_numpy()
# Out:
# array([[0.38, 0.53, 2, ..., 0, 'sales', 'low'],
#        [0.8, 0.86, 5, ..., 0, 'sales', 'medium'],
#        [0.11, 0.88, 7, ..., 0, 'sales', 'medium'],
#        ...,
#        [0.37, 0.53, 2, ..., 0, 'support', 'low'],
#        [0.11, 0.96, 6, ..., 0, 'support', 'low'],
#        [0.37, 0.52, 2, ..., 0, 'support', 'low']], dtype=object)

# %%
df_hr.describe()
# Out:
#        satisfaction_level            le  number_project  average_montly_hours  \
# count        14999.000000  14999.000000    14999.000000          14999.000000
# mean             0.612834      0.716102        3.803054            201.050337
# std              0.248631      0.171169        1.232592             49.943099
# min              0.090000      0.360000        2.000000             96.000000
# 25%              0.440000      0.560000        3.000000            156.000000
# 50%              0.640000      0.720000        4.000000            200.000000
# 75%              0.820000      0.870000        5.000000            245.000000
# max              1.000000      1.000000        7.000000            310.000000
#
#        time_spend_company  Work_accident          left  promotion_last_5years
# count        14999.000000   14999.000000  14999.000000           14999.000000
# mean             3.498233       0.144610      0.238083               0.021268
# ...

# %% [markdown]
# * We get the summary of each DataFrame columns easily without the need for explicit computation
# * By default it includes only the numerical columns
# * Lets get description of object type only in below cells

# %%
df_hr.describe(include="object")
# Out:
#        Department salary
# count       14999  14999
# unique         10      3
# top         sales    low
# freq         4140   7316

# %%
df_hr.describe(exclude=["int", "float"])
# Out:
#        Department salary
# count       14999  14999
# unique         10      3
# top         sales    low
# freq         4140   7316

# %% [markdown]
# * For Object type, we get count, unique, top items with frequency.

# %% [markdown]
# # Data Selection
# * This section covers different techniques to access columns, slice DataFrame, get unique columns values:
#   * select columns (using[], and dot(.) operator)
#   * iloc
#   * loc
#   * unique() and nunique()
#   * value_counts()

# %% [markdown]
# **select columns**

# %%
print(df_hr["satisfaction_level"])

print("---------------------")
# Out:
# 0        0.38
# 1        0.80
# 2        0.11
# 3        0.72
# 4        0.37
#          ...
# 14994    0.40
# 14995    0.37
# 14996    0.37
# 14997    0.11
# 14998    0.37
# Name: satisfaction_level, Length: 14999, dtype: float64
# ---------------------

# %%
df_hr.satisfaction_level
# Out:
# 0        0.38
# 1        0.80
# 2        0.11
# 3        0.72
# 4        0.37
#          ...
# 14994    0.40
# 14995    0.37
# 14996    0.37
# 14997    0.11
# 14998    0.37
# Name: satisfaction_level, Length: 14999, dtype: float64

# %% [markdown]
# # multiple columns

# %%
columns_to_select = ["satisfaction_level", "left"]

# %%
df_hr[columns_to_select]
# Out:
#        satisfaction_level  left
# 0                    0.38     1
# 1                    0.80     1
# 2                    0.11     1
# 3                    0.72     1
# 4                    0.37     1
# ...                   ...   ...
# 14994                0.40     1
# 14995                0.37     1
# 14996                0.37     1
# 14997                0.11     1
# 14998                0.37     1
#
# [14999 rows x 2 columns]

# %% [markdown]
# # iloc
# * ways to slice pandas DataFrame via integer value
# * it allows you to select data fram a DataFrame using integer indices for both rows and columns
# * 1st rows is 0, 2nd row is 1, and so on
# * 1st columns is 0, 2,d columns is 1 and so on.
# *

# %%
df_hr.iloc[0, 1]
# Out:
# 0.53

# %%
df_hr.iloc[:3, -3:]
# Out:
#    promotion_last_5years Department  salary
# 0                      0      sales     low
# 1                      0      sales  medium
# 2                      0      sales  medium

# %%
df_hr.head(3)
# Out:
#    satisfaction_level    le  number_project  average_montly_hours  \
# 0                0.38  0.53               2                   157
# 1                0.80  0.86               5                   262
# 2                0.11  0.88               7                   272
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# 2  medium

# %% [markdown]
# # loc
# * loc is used for label-based indexing
# * Allows us to slice DF using row label and colums label instead of integer values as in loc
# * syntax:
#   ```python
#   df.loc[row_label, column_label]
#   ```

# %%
df_hr.loc[0, "satisfaction_level"]
# Out:
# 0.38

# %%
row_label = [0, 1, 2]
column_label = ["promotion_last_5years", "Department", "salary"]
df_hr.loc[row_label, column_label]
# Out:
#    promotion_last_5years Department  salary
# 0                      0      sales     low
# 1                      0      sales  medium
# 2                      0      sales  medium

# %% [markdown]
# # unique() and nunique()
# * unique() => gives unique values in columns in array
# * nunique() => gives count of unique values

# %%
df_hr["left"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
# This means left columns have 2 unique values 0 and 1

# %%
df_hr["salary"].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
df_hr["salary"].nunique()
# Out:
# 3

# %%
df_hr["left"].value_counts()
# Out:
# left
# 0    11428
# 1     3571
# Name: count, dtype: int64

# %%
df_hr["salary"].value_counts()
# Out:
# salary
# low       7316
# medium    6446
# high      1237
# Name: count, dtype: int64

# %% [markdown]
# # Aggregations
# * Methods are:
#   * mean()
#   * std()
#   * sum()
#   * max()
#   * min()

# %%
num_hr = df_hr["satisfaction_level"].mean()
# num_hr.mean(axis=0)

# %%
cat_hr = df_hr.salary
cat_hr.mode()
# Out:
# 0    low
# Name: salary, dtype: object

# %%
df_hr["satisfaction_level"].sum()
# Out:
# 9191.89

# %% [markdown]
# # Missing Data
# * Finding and Handling missing data
# * methods are
#   * isnull() or isna()
#   * notnull() or notna()
#   * dropna()
#   * fillna()

# %% [markdown]
# # isnull() or isna()
# * returns True if DataFrame values are null
# * DataFrame method to get NAN values from columns
# * it will consider null values if there are NAN which is python default marker for null values
# * you can use df.isnull() mehtods which is simply an alias of df.isna()

# %%
df_hr.isna()
# Out:
#        satisfaction_level     le  number_project  average_montly_hours  \
# 0                   False  False           False                 False
# 1                   False  False           False                 False
# 2                   False  False           False                 False
# 3                   False  False           False                 False
# 4                   False  False           False                 False
# ...                   ...    ...             ...                   ...
# 14994               False  False           False                 False
# 14995               False  False           False                 False
# 14996               False  False           False                 False
# 14997               False  False           False                 False
# 14998               False  False           False                 False
#
#        time_spend_company  Work_accident   left  promotion_last_5years  \
# ...

# %%
df_hr.isna().sum()
# Out:
# satisfaction_level       0
# le                       0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
df_hr.notnull()
# Out:
#        satisfaction_level    le  number_project  average_montly_hours  \
# 0                    True  True            True                  True
# 1                    True  True            True                  True
# 2                    True  True            True                  True
# 3                    True  True            True                  True
# 4                    True  True            True                  True
# ...                   ...   ...             ...                   ...
# 14994                True  True            True                  True
# 14995                True  True            True                  True
# 14996                True  True            True                  True
# 14997                True  True            True                  True
# 14998                True  True            True                  True
#
#        time_spend_company  Work_accident  left  promotion_last_5years  \
# ...

# %%
df_hr.notna().sum(axis=0)
# Out:
# satisfaction_level       14999
# le                       14999
# number_project           14999
# average_montly_hours     14999
# time_spend_company       14999
# Work_accident            14999
# left                     14999
# promotion_last_5years    14999
# Department               14999
# salary                   14999
# dtype: int64

# %%
df_hr.dropna()
# Out:
#        satisfaction_level    le  number_project  average_montly_hours  \
# 0                    0.38  0.53               2                   157
# 1                    0.80  0.86               5                   262
# 2                    0.11  0.88               7                   272
# 3                    0.72  0.87               5                   223
# 4                    0.37  0.52               2                   159
# ...                   ...   ...             ...                   ...
# 14994                0.40  0.57               2                   151
# 14995                0.37  0.48               2                   160
# 14996                0.37  0.53               2                   143
# 14997                0.11  0.96               6                   280
# 14998                0.37  0.52               2                   158
#
#        time_spend_company  Work_accident  left  promotion_last_5years  \
# ...

# %% [markdown]
# # fillna()

# %%
df_hr.fillna(5)
# Out:
#        satisfaction_level    le  number_project  average_montly_hours  \
# 0                    0.38  0.53               2                   157
# 1                    0.80  0.86               5                   262
# 2                    0.11  0.88               7                   272
# 3                    0.72  0.87               5                   223
# 4                    0.37  0.52               2                   159
# ...                   ...   ...             ...                   ...
# 14994                0.40  0.57               2                   151
# 14995                0.37  0.48               2                   160
# 14996                0.37  0.53               2                   143
# 14997                0.11  0.96               6                   280
# 14998                0.37  0.52               2                   158
#
#        time_spend_company  Work_accident  left  promotion_last_5years  \
# ...

# %% [markdown]
# # Data Manipulaton
# * Methods are:
#   * replace()
#     * replace values from DataFrame
#     * df.replace({"old_val": "new_val", "old_val1": "new_val2"})
#   * astype()
#     * change DataFrame column types
#     * df.astype({"col1": "new_type", "col2": "new_type2"})
#   * drop()
#   * sort_values()
#   * groupby()
#   * apply()

# %%
df_hr["left"].replace({1: "yes", 0: "no"}, inplace=True)
df_hr
# Out:
#        satisfaction_level    le  number_project  average_montly_hours  \
# 0                    0.38  0.53               2                   157
# 1                    0.80  0.86               5                   262
# 2                    0.11  0.88               7                   272
# 3                    0.72  0.87               5                   223
# 4                    0.37  0.52               2                   159
# ...                   ...   ...             ...                   ...
# 14994                0.40  0.57               2                   151
# 14995                0.37  0.48               2                   160
# 14996                0.37  0.53               2                   143
# 14997                0.11  0.96               6                   280
# 14998                0.37  0.52               2                   158
#
#        time_spend_company  Work_accident left  promotion_last_5years  \
# ...

# %%
df_typecast = df_hr.astype({"left": "bool"})
df_typecast
# Out:
#        satisfaction_level    le  number_project  average_montly_hours  \
# 0                    0.38  0.53               2                   157
# 1                    0.80  0.86               5                   262
# 2                    0.11  0.88               7                   272
# 3                    0.72  0.87               5                   223
# 4                    0.37  0.52               2                   159
# ...                   ...   ...             ...                   ...
# 14994                0.40  0.57               2                   151
# 14995                0.37  0.48               2                   160
# 14996                0.37  0.53               2                   143
# 14997                0.11  0.96               6                   280
# 14998                0.37  0.52               2                   158
#
#        time_spend_company  Work_accident  left  promotion_last_5years  \
# ...

# %%
df_drop = df_hr.drop("salary", axis=1)
df_drop
# Out:
#        satisfaction_level    le  number_project  average_montly_hours  \
# 0                    0.38  0.53               2                   157
# 1                    0.80  0.86               5                   262
# 2                    0.11  0.88               7                   272
# 3                    0.72  0.87               5                   223
# 4                    0.37  0.52               2                   159
# ...                   ...   ...             ...                   ...
# 14994                0.40  0.57               2                   151
# 14995                0.37  0.48               2                   160
# 14996                0.37  0.53               2                   143
# 14997                0.11  0.96               6                   280
# 14998                0.37  0.52               2                   158
#
#        time_spend_company  Work_accident left  promotion_last_5years  \
# ...

# %%
df_hr.sort_values(by="Work_accident", ascending=False)
# Out:
#        satisfaction_level    le  number_project  average_montly_hours  \
# 8078                 0.77  0.91               5                   268
# 3570                 0.50  0.60               3                   270
# 1784                 0.43  0.51               2                   149
# 6589                 0.64  0.64               3                   234
# 11800                0.67  0.91               2                   245
# ...                   ...   ...             ...                   ...
# 5310                 0.63  0.87               5                   248
# 5311                 0.86  0.75               5                   157
# 5312                 0.80  0.79               5                   240
# 5313                 0.55  0.58               5                   262
# 14998                0.37  0.52               2                   158
#
#        time_spend_company  Work_accident left  promotion_last_5years  \
# ...

# %%
df_hr.sort_values(by="satisfaction_level", ascending=True)
# Out:
#        satisfaction_level    le  number_project  average_montly_hours  \
# 14484                0.09  0.96               6                   296
# 1873                 0.09  0.93               6                   279
# 340                  0.09  0.89               7                   308
# 1882                 0.09  0.89               6                   282
# 332                  0.09  0.98               6                   271
# ...                   ...   ...             ...                   ...
# 12916                1.00  0.86               4                   245
# 4553                 1.00  0.76               6                   246
# 4555                 1.00  0.59               3                   168
# 11122                1.00  0.77               5                   269
# 4724                 1.00  0.73               3                   245
#
#        time_spend_company  Work_accident left  promotion_last_5years  \
# ...

# %%
df_depart_left = df_hr.groupby(df_hr["Department"])
df_depart_left
