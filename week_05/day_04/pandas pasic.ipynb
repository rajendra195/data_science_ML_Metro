# %% [markdown]
# # DataFrame from python dictionary

# %%
import pandas as pd
import csv

# %%
dict = {
    "name": ["Ram", "Shyam", "Hari", "Jane", "Piyush", "Mohan", "Krishna"],
    "age": [34, 23, 22, 53, 22, 21, 32],
    "address": ["bhaktapur", "kathmandu", "Lalitpur", "Bhaktapur", "Bhaktapur", "Kathmandu", "Lalitpur"]
}

# %%
df = pd.DataFrame(dict)
df
# Out:
#       name  age    address
# 0      Ram   34  bhaktapur
# 1    Shyam   23  kathmandu
# 2     Hari   22   Lalitpur
# 3     Jane   53  Bhaktapur
# 4   Piyush   22  Bhaktapur
# 5    Mohan   21  Kathmandu
# 6  Krishna   32   Lalitpur

# %%
list_dict = [
    {"name": "Raj", "age": 23, "address": "Bhaktapur"}, 
    {"name": "Ram", "age": 32, "address": "Bhaktapur"},
    {"name": "Mohan", "age": 33, "address": "Kathmandu"},
    {"name": "Shakti", "age": 22, "address": "lalitpur"},
    {"name": "Gopal", "age": 44, "address": "Banepa"},
    {"name": "Narayan", "age": 22, "address": "Kathmandu"},
    {"name": "Hari", "age": 44, "address": "Dhulikhel"}
]

# %%
df_l = pd.DataFrame(list_dict)
df_l
# Out:
#       name  age    address
# 0      Raj   23  Bhaktapur
# 1      Ram   32  Bhaktapur
# 2    Mohan   33  Kathmandu
# 3   Shakti   22   lalitpur
# 4    Gopal   44     Banepa
# 5  Narayan   22  Kathmandu
# 6     Hari   44  Dhulikhel

# %%
list_tuple = [
     ("Raj", 23, "Bhaktapur"), 
    ("Ram",32,"Bhaktapur"),
    ("Mohan", 33, "Kathmandu"),
    ("Shakti", 22,"lalitpur"),
    ("Gopal", 44,"Banepa"),
    ("Narayan",22, "Kathmandu"),
    ("Hari",  44,"Dhulikhel")
]

# %%
tuple_df = pd.DataFrame(list_tuple,columns=["name", "age", "address"])
tuple_df
# Out:
#       name  age    address
# 0      Raj   23  Bhaktapur
# 1      Ram   32  Bhaktapur
# 2    Mohan   33  Kathmandu
# 3   Shakti   22   lalitpur
# 4    Gopal   44     Banepa
# 5  Narayan   22  Kathmandu
# 6     Hari   44  Dhulikhel

# %%
list_of_list = [
     ["Raj", 23, "Bhaktapur"], 
    ["Ram",32,"Bhaktapur"],
    ["Mohan", 33, "Kathmandu"],
    ["Shakti", 22,"lalitpur"],
    ["Gopal", 44,"Banepa"],
    ["Narayan",22, "Kathmandu"],
    ["Hari",  44,"Dhulikhel"]
]

# %%
list_df = pd.DataFrame(list_of_list, columns=["Name", "Age", "Address"])
list_df
# Out:
#       Name  Age    Address
# 0      Raj   23  Bhaktapur
# 1      Ram   32  Bhaktapur
# 2    Mohan   33  Kathmandu
# 3   Shakti   22   lalitpur
# 4    Gopal   44     Banepa
# 5  Narayan   22  Kathmandu
# 6     Hari   44  Dhulikhel

# %% [markdown]
# #### Question:
# <li>Read 'weather_data.csv' file using csv reader.</li>
# <li>Store the data inside the csv file into a list of lists.</li>
# <li>Then create a pandas dataframe using list of list.</li>

# %%
with open("data/weather_data.csv") as file:
    data = csv.reader(file)
    data = list(data)
    for item in data:
        ll = [data[index] for index in range(3, len(data))]

# %%
pd.DataFrame(ll, columns=[data[2]])
# Out:
#           day    temperature     windspeed     event
# 0    1/1/2017             32             6      Rain
# 1    1/4/2017  not available             9     Sunny
# 2    1/5/2017             -1  not measured      Snow
# 3    1/6/2017  not available             7  no event
# 4    1/7/2017             32  not measured      Rain
# 5    1/8/2017  not available  not measured     Sunny
# 6    1/9/2017  not available  not measured  no event
# 7   1/10/2017             34             8    Cloudy
# 8   1/11/2017             -4            -1      Snow
# 9   1/12/2017             26            12     Sunny
# 10  1/13/2017             12            12     Rainy
# 11  1/11/2017             -1            12      Snow
# 12  1/14/2017             40            -1     Sunny

# %% [markdown]
# #### Question
# <li>1. Read 'imports-85.data' file using file reader.</li>
# <li>2. Store the data present inside the file into a list of list.</li>
# <li>3. Create a pandas dataframe using list of lists.</li>
# <li>4. For column name, we can use the columns variable given below.</li>

# %%
with open("data/imports-85.data") as file:
    data = csv.reader(file)
    data_list = list(data)
data_list
# Out:
# [['3',
#   '?',
#   'alfa-romero',
#   'gas',
#   'std',
#   'two',
#   'convertible',
#   'rwd',
#   'front',
#   '88.60',
#   '168.80',
#   '64.10',
#   '48.80',
#   '2548',
#   'dohc',
#   'four',
#   '130',
#   'mpfi',
#   '3.47',
#   '2.68',
#   '9.00',
#   '111',
#   '5000',
#   '21',
#   '27',
#   '13495'],
#  ['3',
#   '?',
#   'alfa-romero',
#   'gas',
#   'std',
#   'two',
#   'convertible',
#   'rwd',
#   'front',
#   '88.60',
#   '168.80',
#   '64.10',
#   '48.80',
#   '2548',
#   'dohc',
#   'four',
#   '130',
#   'mpfi',
#   '3.47',
#   '2.68',
#   '9.00',
#   '111',
#   '5000',
#   '21',
#   '27',
#   '16500'],
#  ['1',
#   '?',
#   'alfa-romero',
#   'gas',
#   'std',
#   'two',
#   'hatchback',
#   'rwd',
#   'front',
#   '94.50',
#   '171.20',
#   '65.50',
#   '52.40',
#   '2823',
#   'ohcv',
#   'six',
#   '152',
#   'mpfi',
#   '2.68',
#   '3.47',
#   '9.00',
#   '154',
#   '5000',
#   '19',
#   '26',
#   '16500'],
#  ['2',
#   '164',
#   'audi',
#   'gas',
# ...

# %%
import_columns = ['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration', 'num_of_doors',
          'body_style', 'drive_wheels', 'engine_location', 'wheel_base', 'length', 'width', 
           'height', 'curb_weight', 'engine_type', 'num_of_cylinders', 'engine_size', 'fuel_system',
          'bore', 'stroke', 'compression', 'horsepower', 'peak_rpm', 'city_mpg', 'highway_mpg', 'price']

df_85 = pd.DataFrame(data_list, columns=import_columns)
df_85.head()
# Out:
#   symboling normalized_losses         make fuel_type aspiration num_of_doors  \
# 0         3                 ?  alfa-romero       gas        std          two
# 1         3                 ?  alfa-romero       gas        std          two
# 2         1                 ?  alfa-romero       gas        std          two
# 3         2               164         audi       gas        std         four
# 4         2               164         audi       gas        std         four
#
#     body_style drive_wheels engine_location wheel_base  ... engine_size  \
# 0  convertible          rwd           front      88.60  ...         130
# 1  convertible          rwd           front      88.60  ...         130
# 2    hatchback          rwd           front      94.50  ...         152
# 3        sedan          fwd           front      99.80  ...         109
# 4        sedan          4wd           front      99.40  ...         136
#
# ...

# %% [markdown]
# #### Question:
# <li>Read 'weather_data.csv' file using csv reader.</li>
# <li>Store the data inside the csv file into a list of lists.</li>
# <li>Then create a pandas dataframe using list of list.</li>

# %%
with open("data/weather_data.csv") as file:
    data = csv.reader(file)
    data = list(data)
df_data = pd.DataFrame(data)
df_data
# Out:
#               0              1             2         3
# 0    kfjkdfjskd           None          None      None
# 1   dfuhsdjufio           None          None      None
# 2           day    temperature     windspeed     event
# 3      1/1/2017             32             6      Rain
# 4      1/4/2017  not available             9     Sunny
# 5      1/5/2017             -1  not measured      Snow
# 6      1/6/2017  not available             7  no event
# 7      1/7/2017             32  not measured      Rain
# 8      1/8/2017  not available  not measured     Sunny
# 9      1/9/2017  not available  not measured  no event
# 10    1/10/2017             34             8    Cloudy
# 11    1/11/2017             -4            -1      Snow
# 12    1/12/2017             26            12     Sunny
# 13    1/13/2017             12            12     Rainy
# 14    1/11/2017             -1            12      Snow
# 15    1/14/2017             40            -1     Sunny

# %%
weather_df = pd.read_csv("data/weather_data.csv", skiprows=2)
weather_df
# Out:
#           day    temperature     windspeed     event
# 0    1/1/2017             32             6      Rain
# 1    1/4/2017  not available             9     Sunny
# 2    1/5/2017             -1  not measured      Snow
# 3    1/6/2017  not available             7  no event
# 4    1/7/2017             32  not measured      Rain
# 5    1/8/2017  not available  not measured     Sunny
# 6    1/9/2017  not available  not measured  no event
# 7   1/10/2017             34             8    Cloudy
# 8   1/11/2017             -4            -1      Snow
# 9   1/12/2017             26            12     Sunny
# 10  1/13/2017             12            12     Rainy
# 11  1/11/2017             -1            12      Snow
# 12  1/14/2017             40            -1     Sunny

# %%
weather_df.drop(index=1, inplace=True)
weather_df
# Out:
#           day    temperature     windspeed     event
# 0    1/1/2017             32             6      Rain
# 2    1/5/2017             -1  not measured      Snow
# 3    1/6/2017  not available             7  no event
# 4    1/7/2017             32  not measured      Rain
# 5    1/8/2017  not available  not measured     Sunny
# 6    1/9/2017  not available  not measured  no event
# 7   1/10/2017             34             8    Cloudy
# 8   1/11/2017             -4            -1      Snow
# 9   1/12/2017             26            12     Sunny
# 10  1/13/2017             12            12     Rainy
# 11  1/11/2017             -1            12      Snow
# 12  1/14/2017             40            -1     Sunny

# %%
weather_df.reset_index(drop=True, inplace=True)
weather_df
# Out:
#           day    temperature     windspeed     event
# 0    1/1/2017             32             6      Rain
# 1    1/5/2017             -1  not measured      Snow
# 2    1/6/2017  not available             7  no event
# 3    1/7/2017             32  not measured      Rain
# 4    1/8/2017  not available  not measured     Sunny
# 5    1/9/2017  not available  not measured  no event
# 6   1/10/2017             34             8    Cloudy
# 7   1/11/2017             -4            -1      Snow
# 8   1/12/2017             26            12     Sunny
# 9   1/13/2017             12            12     Rainy
# 10  1/11/2017             -1            12      Snow
# 11  1/14/2017             40            -1     Sunny

# %%
df = pd.read_csv("data/weather_data.csv", header=2)
df
# Out:
#           day    temperature     windspeed     event
# 0    1/1/2017             32             6      Rain
# 1    1/4/2017  not available             9     Sunny
# 2    1/5/2017             -1  not measured      Snow
# 3    1/6/2017  not available             7  no event
# 4    1/7/2017             32  not measured      Rain
# 5    1/8/2017  not available  not measured     Sunny
# 6    1/9/2017  not available  not measured  no event
# 7   1/10/2017             34             8    Cloudy
# 8   1/11/2017             -4            -1      Snow
# 9   1/12/2017             26            12     Sunny
# 10  1/13/2017             12            12     Rainy
# 11  1/11/2017             -1            12      Snow
# 12  1/14/2017             40            -1     Sunny

# %%
# reading csv file without header and giving custom column name or header
weather_df = pd.read_csv("data/weather_data.csv", skiprows=3, header=None, names=["Data", "temperature", "windspeed", "Event"])
weather_df
# Out:
#          Data    temperature     windspeed     Event
# 0    1/1/2017             32             6      Rain
# 1    1/4/2017  not available             9     Sunny
# 2    1/5/2017             -1  not measured      Snow
# 3    1/6/2017  not available             7  no event
# 4    1/7/2017             32  not measured      Rain
# 5    1/8/2017  not available  not measured     Sunny
# 6    1/9/2017  not available  not measured  no event
# 7   1/10/2017             34             8    Cloudy
# 8   1/11/2017             -4            -1      Snow
# 9   1/12/2017             26            12     Sunny
# 10  1/13/2017             12            12     Rainy
# 11  1/11/2017             -1            12      Snow
# 12  1/14/2017             40            -1     Sunny

# %%
weather_df.columns
# Out:
# Index(['Data', 'temperature', 'windspeed', 'Event'], dtype='object')

# %% [markdown]
# # Read limited data from a csv file using nrows parameter

# %%
weather_df = pd.read_csv("data/weather_data.csv", skiprows=3, nrows=5, header=None, names=["Date", "Temperature", "Windsped", "Event"])
weather_df
# Out:
#        Date    Temperature      Windsped     Event
# 0  1/1/2017             32             6      Rain
# 1  1/4/2017  not available             9     Sunny
# 2  1/5/2017             -1  not measured      Snow
# 3  1/6/2017  not available             7  no event
# 4  1/7/2017             32  not measured      Rain

# %% [markdown]
# # Questions
# * Reading a csv file using na_values parameters("weather_data.csv" file)

# %%
weather_df = pd.read_csv("data/weather_data.csv", skiprows=2, na_values=["not available", "not measured", "no event"])
weather_df
# Out:
#           day  temperature  windspeed   event
# 0    1/1/2017         32.0        6.0    Rain
# 1    1/4/2017          NaN        9.0   Sunny
# 2    1/5/2017         -1.0        NaN    Snow
# 3    1/6/2017          NaN        7.0     NaN
# 4    1/7/2017         32.0        NaN    Rain
# 5    1/8/2017          NaN        NaN   Sunny
# 6    1/9/2017          NaN        NaN     NaN
# 7   1/10/2017         34.0        8.0  Cloudy
# 8   1/11/2017         -4.0       -1.0    Snow
# 9   1/12/2017         26.0       12.0   Sunny
# 10  1/13/2017         12.0       12.0   Rainy
# 11  1/11/2017         -1.0       12.0    Snow
# 12  1/14/2017         40.0       -1.0   Sunny

# %%
weather_df.dropna(axis=0, inplace=True)
weather_df.reset_index(inplace=True, drop=True)
weather_df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1  1/10/2017         34.0        8.0  Cloudy
# 2  1/11/2017         -4.0       -1.0    Snow
# 3  1/12/2017         26.0       12.0   Sunny
# 4  1/13/2017         12.0       12.0   Rainy
# 5  1/11/2017         -1.0       12.0    Snow
# 6  1/14/2017         40.0       -1.0   Sunny

# %% [markdown]
# #  Write a pandas DF to a csv file

# %%
csv_file = weather_df.to_csv("data/weather_nan.csv", index=False)

# %%
weather_df.to_numpy()
# Out:
# array([['1/1/2017', 32.0, 6.0, 'Rain'],
#        ['1/10/2017', 34.0, 8.0, 'Cloudy'],
#        ['1/11/2017', -4.0, -1.0, 'Snow'],
#        ['1/12/2017', 26.0, 12.0, 'Sunny'],
#        ['1/13/2017', 12.0, 12.0, 'Rainy'],
#        ['1/11/2017', -1.0, 12.0, 'Snow'],
#        ['1/14/2017', 40.0, -1.0, 'Sunny']], dtype=object)

# %% [markdown]
# # DataFrame to NumPy array

# %%
weather_df.values
# Out:
# array([['1/1/2017', 32.0, 6.0, 'Rain'],
#        ['1/10/2017', 34.0, 8.0, 'Cloudy'],
#        ['1/11/2017', -4.0, -1.0, 'Snow'],
#        ['1/12/2017', 26.0, 12.0, 'Sunny'],
#        ['1/13/2017', 12.0, 12.0, 'Rainy'],
#        ['1/11/2017', -1.0, 12.0, 'Snow'],
#        ['1/14/2017', 40.0, -1.0, 'Sunny']], dtype=object)
