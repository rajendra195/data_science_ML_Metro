# %% [markdown]
# # R2 score checking

# %%
import pandas as pd

data = {
        "X": [8, 2, 10, 6, 5, 4, 12, 9, 6, 1], 
        "Y": [3, 10, 3, 6, 8, 12, 1, 4, 9, 14]
}


df = pd.DataFrame(data)

# %%
df
# Out:
#     X   Y
# 0   8   3
# 1   2  10
# 2  10   3
# 3   6   6
# 4   5   8
# 5   4  12
# 6  12   1
# 7   9   4
# 8   6   9
# 9   1  14

# %%
X = df[["X"]]
y = df["Y"]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
y_pred
# Out:
# array([ 5.0390554 , 11.96003633,  2.73206176,  7.34604905,  8.49954587,
#         9.65304269,  0.42506812,  3.88555858,  7.34604905, 13.11353315])

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_true=y, y_pred=y_pred)
r2
# Out:
# 0.8824945558801965

# %% [markdown]
# # Karl Pearson's correlation coffecient

# %%
data = {
    "X": [12, 9, 8, 10, 11, 13, 7], 
    "Y": [14, 8, 6, 9, 11, 12, 13]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     X   Y
# 0  12  14
# 1   9   8
# 2   8   6
# 3  10   9
# 4  11  11
# 5  13  12
# 6   7  13

# %%
from scipy.stats import pearsonr

corr, pvalue = pearsonr(df["X"], df["Y"])
corr, pvalue
# Out:
# (0.4288450139351179, 0.3370258241670751)
