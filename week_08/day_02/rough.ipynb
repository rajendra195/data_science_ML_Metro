# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
# df.sepal_length.value_counts()

# %%
df.drop(df[df.sepal_length == 7.9].index, inplace=True)

# %%
# df.sepal_length.value_counts()

# %%
# import pandas as pd

# # Create a DataFrame with a gender column
# data = {'gender': ['Male', 'Female', 'Female', 'Male', 'Male', 'Non-binary']}
# df = pd.DataFrame(data)
# df.gender.value_counts

# %%
# Apply the code to count gender categories
# df["gender"] = df.gender.astype("category").cat.codes.value_counts()
# # .cat.codes.value_counts()

# %%
# df["gender"].dtypes

# %%
# df["gender"]

# %%
# df.gender.value_counts()

# %%
df1 = df.groupby(["species"]).agg({"sepal_length": ["sum", "mean"]})
df2 = df.groupby(["species", "sepal_length"]).agg(["sum", "mean"])
df3 = df.groupby(["species"])["sepal_length"].agg(["sum", "mean"])

# %%
df1
# Out:
#            sepal_length
#                     sum      mean
# species
# setosa            250.3  5.006000
# versicolor        296.8  5.936000
# virginica         321.5  6.561224

# %%
df2
# Out:
#                         sepal_width           petal_length            \
#                                 sum      mean          sum      mean
# species    sepal_length
# setosa     4.3                  3.0  3.000000          1.1  1.100000
#            4.4                  9.1  3.033333          4.0  1.333333
#            4.5                  2.3  2.300000          1.3  1.300000
#            4.6                 13.3  3.325000          5.3  1.325000
#            4.7                  6.4  3.200000          2.9  1.450000
#            4.8                 15.9  3.180000          7.9  1.580000
#            4.9                 12.8  3.200000          5.8  1.450000
#            5.0                 26.9  3.362500         11.6  1.450000
#            5.1                 28.8  3.600000         12.5  1.562500
#            5.2                 11.0  3.666667          4.4  1.466667
#            5.3                  3.7  3.700000          1.5  1.500000
#            5.4                 18.3  3.660000          7.7  1.540000
#            5.5                  7.7  3.850000          2.7  1.350000
#            5.7                  8.2  4.100000          3.2  1.600000
#            5.8                  4.0  4.000000          1.2  1.200000
# versicolor 4.9                  2.4  2.400000          3.3  3.300000
#            5.0                  4.3  2.150000          6.8  3.400000
#            5.1                  2.5  2.500000          3.0  3.000000
#            5.2                  2.7  2.700000          3.9  3.900000
#            5.4                  3.0  3.000000          4.5  4.500000
#            5.5                 12.2  2.440000         19.9  3.980000
#            5.6                 14.1  2.820000         20.3  4.060000
#            5.7                 14.1  2.820000         20.5  4.100000
#            5.8                  8.0  2.666667         12.0  4.000000
#            5.9                  6.2  3.100000          9.0  4.500000
#            6.0                 11.2  2.800000         18.1  4.525000
#            6.1                 11.5  2.875000         18.0  4.500000
#            6.2                  5.1  2.550000          8.8  4.400000
#            6.3                  8.1  2.700000         14.0  4.666667
#            6.4                  6.1  3.050000          8.8  4.400000
#            6.5                  2.8  2.800000          4.6  4.600000
#            6.6                  5.9  2.950000          9.0  4.500000
#            6.7                  9.2  3.066667         14.1  4.700000
#            6.8                  2.8  2.800000          4.8  4.800000
#            6.9                  3.1  3.100000          4.9  4.900000
#            7.0                  3.2  3.200000          4.7  4.700000
# virginica  4.9                  2.5  2.500000          4.5  4.500000
#            5.6                  2.8  2.800000          4.9  4.900000
#            5.7                  2.5  2.500000          5.0  5.000000
#            5.8                  8.2  2.733333         15.3  5.100000
#            5.9                  3.0  3.000000          5.1  5.100000
#            6.0                  5.2  2.600000          9.8  4.900000
#            6.1                  5.6  2.800000         10.5  5.250000
#            6.2                  6.2  3.100000         10.2  5.100000
#            6.3                 17.6  2.933333         32.2  5.366667
#            6.4                 14.6  2.920000         27.3  5.460000
#            6.5                 12.2  3.050000         21.6  5.400000
#            6.7                 15.2  3.040000         28.0  5.600000
#            6.8                  6.2  3.100000         11.4  5.700000
#            6.9                  9.4  3.133333         16.2  5.400000
#            7.1                  3.0  3.000000          5.9  5.900000
#            7.2                  9.8  3.266667         17.9  5.966667
#            7.3                  2.9  2.900000          6.3  6.300000
#            7.4                  2.8  2.800000          6.1  6.100000
#            7.6                  3.0  3.000000          6.6  6.600000
#            7.7                 12.2  3.050000         26.4  6.600000
#
#                         petal_width
#                                 sum      mean
# species    sepal_length
# setosa     4.3                  0.1  0.100000
#            4.4                  0.6  0.200000
#            4.5                  0.3  0.300000
#            4.6                  0.9  0.225000
#            4.7                  0.4  0.200000
#            4.8                  1.0  0.200000
#            4.9                  0.6  0.150000
#            5.0                  2.3  0.287500
#            5.1                  2.5  0.312500
#            5.2                  0.5  0.166667
#            5.3                  0.2  0.200000
#            5.4                  1.6  0.320000
#            5.5                  0.4  0.200000
#            5.7                  0.7  0.350000
#            5.8                  0.2  0.200000
# versicolor 4.9                  1.0  1.000000
#            5.0                  2.0  1.000000
#            5.1                  1.1  1.100000
#            5.2                  1.4  1.400000
#            5.4                  1.5  1.500000
#            5.5                  5.9  1.180000
#            5.6                  6.5  1.300000
#            5.7                  6.1  1.220000
#            5.8                  3.4  1.133333
#            5.9                  3.3  1.650000
#            6.0                  5.7  1.425000
#            6.1                  5.3  1.325000
#            6.2                  2.8  1.400000
#            6.3                  4.4  1.466667
#            6.4                  2.8  1.400000
#            6.5                  1.5  1.500000
#            6.6                  2.7  1.350000
#            6.7                  4.6  1.533333
#            6.8                  1.4  1.400000
#            6.9                  1.5  1.500000
#            7.0                  1.4  1.400000
# virginica  4.9                  1.7  1.700000
#            5.6                  2.0  2.000000
#            5.7                  2.0  2.000000
#            5.8                  6.2  2.066667
#            5.9                  1.8  1.800000
#            6.0                  3.3  1.650000
#            6.1                  3.2  1.600000
#            6.2                  4.1  2.050000
#            6.3                 11.9  1.983333
#            6.4                 10.3  2.060000
#            6.5                  8.0  2.000000
#            6.7                 11.1  2.220000
#            6.8                  4.4  2.200000
#            6.9                  6.7  2.233333
#            7.1                  2.1  2.100000
#            7.2                  5.9  1.966667
#            7.3                  1.8  1.800000
#            7.4                  1.9  1.900000
#            7.6                  2.1  2.100000
#            7.7                  8.8  2.200000

# %%
data = {
    "x": ["a,b,c,d", "a,c,d", "a"],
}
df = pd.DataFrame(data)

# %%
df
# Out:
#          x
# 0  a,b,c,d
# 1    a,c,d
# 2        a

# %%
df[["a", "b", "c", "d"]] = df.x.str.split(",", expand=True)

# %%
df
# Out:
#          x  a     b     c     d
# 0  a,b,c,d  a     b     c     d
# 1    a,c,d  a     c     d  None
# 2        a  a  None  None  None

# %%
data = {
    "x": ["a,b,c,d", "a,c,d", "a"],
}
df = pd.DataFrame(data)
print(df)
df[["a", "b", "c", "d"]] = df.x.str.split(",", expand=True)
print(df)
# Out:
#          x
# 0  a,b,c,d
# 1    a,c,d
# 2        a
#          x  a     b     c     d
# 0  a,b,c,d  a     b     c     d
# 1    a,c,d  a     c     d  None
# 2        a  a  None  None  None

# %%
df
# Out:
#          x  a     b     c     d
# 0  a,b,c,d  a     b     c     d
# 1    a,c,d  a     c     d  None
# 2        a  a  None  None  None

# %%
pd.get_dummies(df, columns=["c", "d"])
# Out:
#          x  a     b    c_c    c_d    d_d
# 0  a,b,c,d  a     b   True  False   True
# 1    a,c,d  a     c  False   True  False
# 2        a  a  None  False  False  False

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
enc.fit(df[["b"]])
# Out:
# OneHotEncoder()
