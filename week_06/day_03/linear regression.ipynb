# %%
# y = 2 * x + 3

# %%
import matplotlib.pyplot as plt
import numpy as np

x_data = np.arange(1, 6)

y_data = [2 * x + 3 for x in x_data]

interval = zip(x_data, y_data)
interval = [item for item in interval]
print(interval)

plt.plot(x_data, y_data, "o-")   
plt.show()
# Out:
# [(1, 5), (2, 7), (3, 9), (4, 11), (5, 13)]
