# %% [markdown]
# Hey everyone! As discussed in class, let's plot graphs for four different equations using independent variables ranging from 100 to 200. Plot the graphs for Simple Linear Regression, Multiple Linear Regression, Simple Polynomial Regression (Degree 2), and Multiple Polynomial Regression (Degree 3).
#
# Additionally, let's figure out how to obtain continuous values from the attached CSV files using you'll:
#
# For Position_Salaries.csv, you'll perform Simple Polynomial Regression (Degree 2) and Multiple Polynomial Regression (Degree 3).
# For Salary_Data.csv, you'll conduct Simple Linear Regression.
# For 50_Startups.csv, you'll employ Multiple Linear Regression.

# %% [markdown]
# # 1. Simple Linear regression (y = 2x + 3)

# %%
import matplotlib.pyplot as plt
import numpy as np

# x data from 100 to 200
x_data = np.arange(10, 20)

# respective y data with the value of x
y_data = [2 * x + 3 for x in x_data]

# plotting x data and y data
plt.figure(figsize=(10, 8))
plt.plot(x_data, y_data, "o-") 

plt.xlabel("x data")
plt.ylabel("y data")
plt.title("Simple linear regression of 'y = 2x + 3'")
# plt.scatter(x_data, y_data)

plt.grid()
plt.show()

# %% [markdown]
# # 2. Multiple Linear regression (y = 3$x_{1}$ + 2$x_{2}$ + 4$x_{3}$ + 5)

# %%
import pandas as pd

# %% [markdown]
# # 3. Simple Polynomial Regression (y = 2$x^2$ + 3x + 4)

# %% [markdown]
# # 4. Multiple Polynomial Regression (y = 2$x^3$ + 3$x^2$ + 4x + 5)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generating random values for x1, x2, and x3
num_points = 100
x1 = np.random.uniform(low=-10, high=10, size=num_points)
x2 = np.random.uniform(low=-10, high=10, size=num_points)
x3 = np.random.uniform(low=-10, high=10, size=num_points)

# Calculating the values of the expression for each combination of x1, x2, and x3
y = 3*x1 + 4*x2 + 5*x3 + 5

# Plotting
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x1, x2, x3, c=y, cmap='viridis')
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('X3')
ax.set_title('Multiple Linear Expression: 3x1 + 4x2 + 5x3 + 5')
plt.show()
