# %% [markdown]
# # Simple Linear Regression
# * In this lab we will use simple linear regression to predict the car price.
# * Objective
#   * To know if the dealer is offering fair value for my trade-in.
#   * To know if I put a fair value on my car.

# %%
import pandas as pd

# %%
df = pd.read_csv("automobileEDA.csv")
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
df.shape
# Out:
# (201, 29)

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    int64
#  2   make               201 non-null    object
#  3   aspiration         201 non-null    object
#  4   num-of-doors       201 non-null    object
#  5   body-style         201 non-null    object
#  6   drive-wheels       201 non-null    object
#  7   engine-location    201 non-null    object
#  8   wheel-base         201 non-null    float64
#  9   length             201 non-null    float64
#  10  width              201 non-null    float64
#  11  height             201 non-null    float64
#  12  curb-weight        201 non-null    int64
#  13  engine-type        201 non-null    object
#  14  num-of-cylinders   201 non-null    object
#  15  engine-size        201 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'horsepower-binned', 'diesel', 'gas'],
#       dtype='object')

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
df.describe(include="object")
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               4
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    1
# diesel               0
# gas                  0
# dtype: int64

# %%
df["price"]
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 196    16845.0
# 197    19045.0
# 198    21485.0
# 199    22470.0
# 200    22625.0
# Name: price, Length: 201, dtype: float64

# %% [markdown]
# # We will use dataset of Car price prediction hosted on IBM Cloud object.

# %%
import os # file path
import numpy as np # statistical data 
import pandas as pd # data analysis
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # data visuslization
from sklearn.model_selection import train_test_split # to split data in training and testing
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df_auto = pd.read_csv("automobileEDA.csv")
df_auto.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
X = df_auto.drop("price", axis=1) # independent features
Y = df_auto['price'] # dependent features

# %% [markdown]
# # Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
X_test
# Out:
#      symboling  normalized-losses           make aspiration num-of-doors  \
# 97           0                106         nissan        std         four
# 117          1                154       plymouth        std         four
# 59           0                115          mazda        std         four
# 35           0                 78          honda        std         four
# 165          2                134         toyota        std          two
# 147          1                 87         toyota        std          two
# 28           3                145          dodge      turbo          two
# 78           3                153     mitsubishi        std          two
# 4            2                164           audi        std         four
# 18           1                 98      chevrolet        std          two
# 169         -1                 65         toyota        std         four
# 34           0                110          honda        std         four
# ...

# %% [markdown]
# # Simple Linear Regression
# **Predict Car Price using "highway-mph"**

# %%
X_train_simple = X_train["highway-mpg"].values.reshape(-1, 1)
X_test_simple = X_test["highway-mpg"].values.reshape(-1, 1)
# X_train_simple, X_train_simple.shape

# %%
# X_test_simple

# %%
simple_lm = LinearRegression()
simple_lm.fit(X_train_simple, y_train)
# Out:
# LinearRegression()

# %%
y_hat_simple = simple_lm.predict(X_test_simple)
y_hat_simple[:5]
# Out:
# array([10530.19044542,  7150.17926639, 12220.19603494, 10530.19044542,
#        13910.20162445])

# %%
c = simple_lm.intercept_

# %%
m = simple_lm.coef_.item()

# %%
price = c + m * df["highway-mpg"]
price
# Out:
# 0      16445.210009
# 1      16445.210009
# 2      17290.212803
# 3      13910.201624
# 4      20670.223983
#            ...
# 196    15600.207214
# 197    18135.215598
# 198    19825.221188
# 199    16445.210009
# 200    18135.215598
# Name: highway-mpg, Length: 201, dtype: float64

# %% [markdown]
# # Exercise
#     * Fit Simple Linear Regression with engine-size as independent variable to predict car price.
#     * Fit simple linear regression with horsepower as independent variable to predict car price.

# %%
X_simple_train = X_train["engine-size"].values.reshape(-1, 1)
X_simple_test = X_test["engine-size"].values.reshape(-1, 1)

# %%
model = LinearRegression()
model.fit(X_simple_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_simple_test)
y_pred[:5]
# Out:
# array([12200.90004806,  7203.38742473, 12534.06755628,  7536.55493295,
#        16532.07765495])

# %%
m = model.coef_.item()
m
# Out:
# 166.58375411113175

# %%
c = model.intercept_
c
# Out:
# -7789.150445273459

# %%
price = c + m * df["engine-size"]
price
# Out:
# 0      13866.737589
# 1      13866.737589
# 2      17531.580180
# 3      10368.478753
# 4      14866.240114
#            ...
# 196    15699.158884
# 197    15699.158884
# 198    21029.839016
# 199    16365.493901
# 200    15699.158884
# Name: engine-size, Length: 201, dtype: float64

# %% [markdown]
# # Horsepower as independent variable

# %%
# Training Testing data in 2D format
X_simple_train = X_train["horsepower"].values.reshape(-1, 1)
X_simple_test = X_test["horsepower"].values.reshape(-1, 1)

# %% [markdown]
# # Training model

# %%
model = LinearRegression()
model.fit(X_simple_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_simple_test)
y_pred[:5]
# Out:
# array([12166.10030237,  7173.74640389,  9928.14855478,  8550.94747933,
#        15436.95285656])

# %%
m = model.coef_.item()
m
# Out:
# 172.15013443062284

# %%
c = model.intercept_
c
# Out:
# -4532.462737395461

# %%
price = m * df["horsepower"] + c
price
# Out:
# 0      14576.202184
# 1      14576.202184
# 2      21978.657965
# 3      13026.850975
# 4      15264.802722
#            ...
# 196    15092.652588
# 197    23011.558772
# 198    18535.655276
# 199    13715.451512
# 200    15092.652588
# Name: horsepower, Length: 201, dtype: float64

# %% [markdown]
# # Multiple Linear Regression
# * As seen in Simple linear regression, we used single independent variable for car price prediction.
# * However, in real world datasets, for accurate prediction of car price, we need to consider multiple features/variables instead of single one. In such scenario Multiple Linear Regression would be helpful.

# %% [markdown]
# ### Predict car price using variables[horsepower, curb-weight, engine-size, highway-mpn]

# %%
df.head(2)
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# 0                9.0       111.0    5000.0       21          27  13495.0
# 1                9.0       111.0    5000.0       21          27  16500.0
#
#   city-L/100km  horsepower-binned  diesel  gas
# 0    11.190476             Medium       0    1
# 1    11.190476             Medium       0    1
#
# [2 rows x 29 columns]

# %%
df_auto = pd.read_csv("automobileEDA.csv")
df_auto.head()
X = df_auto.drop("price", axis=1) # independent features
Y = df_auto['price'] # dependent features
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
to_select = ["horsepower", "curb-weight", "engine-size", "highway-mpg"]
X_train_mult = X_train[to_select].values
X_test_mult = X_test[to_select].values

# %%
model = LinearRegression()
model.fit(X_train_mult, y_train)
# Out:
# LinearRegression()

# %%
# Model prediction
y_hat_mult = model.predict(X_test_mult)
y_hat_mult[:5]
# Out:
# array([11457.56050541,  5966.17033563, 11313.13362185,  6839.1134896 ,
#        15765.36249767])

# %%
# coefficient/ slope/ m
m = model.coef_
m
# Out:
# array([ 54.23019834,   3.1154028 ,  93.34038826, -18.71070774])

# %%
# intercept/ c
c = model.intercept_
c
# Out:
# -11539.108515802094

# %%
# np.sort(df["price"])

# %%
# Estimated equation of best fit line is:
Price = c + m[0] * df["horsepower"] + m[1] * df["curb-weight"] + m[2] * df["engine-size"] + m[3] * df["highway-mpg"]
# np.sort(Price)

# %% [markdown]
# # Multiple Linear regression evaluation using r-square

# %%
data = y_test - y_hat_mult
up = [item ** 2 for item in data]
ssr = sum(up)

data2 = y_test - y_test.mean()
below = [item **2 for item in data2]
sst = sum(below)

r_square = 1 - ssr / sst
r_square
# Out:
# 0.7429274527307541

# %%
def calc_ssr(y_true, y_pred):
    """calculate ssr
        * """
    data = y_true - y_pred
    up = [item ** 2 for item in data]
    ssr = sum(up)
    return ssr

def calc_sst(y_true):
    data = y_true - y_true.mean()
    below = [item **2 for item in data2]
    sst = sum(below)
    return sst

def calc_r2_score(y_true, y_pred):
    ssr = calc_ssr(y_true=y_true, y_pred=y_pred)
    sst = calc_sst(y_true=y_true)
    return 1 - (ssr / sst)

# %%
calc_r2_score(y_true=y_test, y_pred=y_hat_mult)
# Out:
# 0.7429274527307541

# %% [markdown]
# # Adjusted R2

# %%
adjusted_r2 = 1 - ((1- r_square) * (len(y_test - 1)) / (len(y_test) - len(to_select) - 1))
adjusted_r2
# Out:
# 0.7072229322766922

# %% [markdown]
# # Mean squared Error

# %%
mse = ssr / len(y_test)
mse
# Out:
# 13623765.520788323

# %% [markdown]
# # Mean absolute error

# %%
import math
mae = math.sqrt(mse)
mae
# Out:
# 3691.0385423059893

# %% [markdown]
# # Excercise:
#     * Fit multiple linear regression with [engine-size, horsepower] as independent variable to predict car price
#     * Fit multiple linear regression with [normalized-losses, highway-mpg] as independent variable to predict car price

# %%
# Fit multiple linear regression with [engine-size, horsepower] as independent variable to predict car price
X_train_mul = X_train[["engine-size", "horsepower"]].values
X_test_mul = X_test[["engine-size", "horsepower"]].values

# %%
# modeling
model = LinearRegression()
model.fit(X_train_mul, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test_mul)
y_pred[:5]
# Out:
# array([12077.52113264,  6628.90601721, 11483.76279299,  7380.92800977,
#        16406.60092931])

# %%
m = model.coef_
m
# Out:
# array([119.67188538,  64.08477772])

# %%
c = model.intercept_
c
# Out:
# -8499.328552319712

# %%
# predicted price
price = c + m[0] * df["engine-size"] + m[1] * df["horsepower"]

# %%
# regression line between estimated equation of best fit line vs engine-size and horsepower
plt.figure(figsize=(12, 6))
sns.regplot(x="engine-size", y=price, data=df, label="predicted")
sns.regplot(x="engine-size", y="price", data=df, label="actual")

plt.xlabel("engine-size")
plt.ylabel("Predicted Price")
plt.legend()
plt.show()

# %%
# regression line between actual price vs engine-size and horsepower
plt.figure(figsize=(12, 6))
sns.regplot(x="horsepower", y=price, data=df)
sns.regplot(x="horsepower", y="price", data=df)

plt.title("predicted_price vs horsepower")
plt.xlabel("Horsepower")
plt.ylabel("price")
plt.show()

# %%
# Distribution plot
plt.figure(figsize=(12, 6))
sns.distplot(y_test, hist=False, label="Actual values")
sns.distplot(y_pred, hist=False, label="predicted value")

plt.legend()
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_6716\2905189485.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test, hist=False, label="Actual values")
# C:\Users\Hp\AppData\Local\Temp\ipykernel_6716\2905189485.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ###  Fit multiple linear regression with [normalized-losses, highway-mpg] as independent variable to predict car price

# %%
X_train_lin = X_train[["highway-mpg", "normalized-losses"]].values
X_test_lin = X_test[["highway-mpg", "normalized-losses"]].values

# %%
# model 
model = LinearRegression()
model.fit(X_train_lin, y_train)
# Out:
# LinearRegression()

# %%
# Model prediction
y_pred = model.predict(X_test_lin)
y_pred[:5]
# Out:
# array([10539.09958308,  7126.02000108, 12224.24991436, 10557.24821556,
#        13902.9185912 ])

# %%
# coef_
m = model.coef_
m
# Out:
# array([-8.45491910e+02, -6.48165446e-01])

# %%
# intercept
c = model.intercept_
c
# Out:
# 39354.53006543252

# %%
# equation of best fit line
price = c + m[0] * df["highway-mpg"] + m[1] * df["normalized-losses"]
price
# Out:
# 0      16447.172307
# 1      16447.172307
# 2      17292.664217
# 3      13883.473628
# 4      20647.408909
#            ...
# 196    15619.180864
# 197    18155.656594
# 198    19846.640415
# 199    16464.672774
# 200    18155.656594
# Length: 201, dtype: float64

# %%
# Visualization
plt.figure(figsize=(12, 6))
sns.regplot(x="normalized-losses", y=price, data=df)
sns.regplot(x="normalized-losses", y="price", data=df)

plt.title("regression line beteen normalized-losses vs estimated equaiton of best fit line( predicted price) and actual price")
plt.show()
plt.close()

# %% [markdown]
# # Mean Squared Error

# %%
# Error
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_true=y_test, y_pred=y_hat_mult)
mse
# Out:
# 13623765.520788323

# %% [markdown]
# # Mean absolute Error

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_true=y_test, y_pred=y_hat_mult)
mae
# Out:
# 2737.0634011548564

# %% [markdown]
# # R2 score

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_true=y_test, y_pred=y_hat_mult)
r2
# Out:
# 0.7429274527307541

# %% [markdown]
# # Model evaluation using Visualization
# * Now we have we developed our simple Linear Regression and Multiple Linear Regression model
# * How do we evaluated them?
# * We can evaluate our linear regression either visually or numerically
# * Let's first evaluate our linear regression model visually using Regression plot and Distribution plot

# %%
plt.figure(figsize=(12, 6))
sns.regplot(x="highway-mpg", y="price", data=df)
plt.show()

# %% [markdown]
# * we see slope of the line is negative, which we predicted earlier when fitting simple linear regression line.
# * More dispersed is the data point from the regression lilne, it will be not suitable to model such data point with linear regression.
# * Hence, if the data is too far from the line, this linear model might not be the best fit model for this data.
# * In above plot, data is not perfectly linear, so simple polynomial regression can do a better job, since it capture non linear data.

# %%
plt.figure(figsize=(12, 6))
sns.regplot(x="engine-size", y="price", data=df)
plt.show()

# %% [markdown]
# * This shows that increase in engine size increases the Price of the Car i,e positive correlation.

# %%
plt.figure(figsize=(12, 6))
sns.regplot(x="horsepower", y="price", data=df)
plt.show()

# %% [markdown]
# # Distribution plot
# * We successfully visualize simple linear regression model using Regression plot. It will be complicated for multiple linear regression since there will be multiple independent variables, in such scenarios we could be using Distribution plot.
# * Now let's visualize our prediction from linear regression model using Distribution plot.

# %%
# 1. simple linear regression
plt.figure(figsize=(12, 6))
ax1 = sns.distplot(y_test, hist=False, color="r", label="Actual value")
sns.distplot(y_hat_simple, hist=False, color="b", label="fitted values", ax=ax1)

plt.title("simple linear regression Actual vs fited values for price")
plt.xlabel("price (in dollars)")
plt.ylabel("proportion of cars")

plt.legend()
plt.show()
plt.close()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_6716\404351021.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(y_test, hist=False, color="r", label="Actual value")
# C:\Users\Hp\AppData\Local\Temp\ipykernel_6716\404351021.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
# Multiple linear regression
plt.figure(figsize=(12, 6))
ax1 = sns.distplot(y_test, hist=False, color="r", label="Actual price")
sns.distplot(y_hat_mult, hist=False, color="b", label="fitted values", ax=ax1)

plt.title("multiple linear regression actual vs fitted values for prices")
plt.xlabel("Price (in dollars)")
plt.ylabel("Proportion of cars")

plt.legend()

plt.show()
plt.close()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_6716\1425615908.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(y_test, hist=False, color="r", label="Actual price")
# C:\Users\Hp\AppData\Local\Temp\ipykernel_6716\1425615908.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# # From above 2 Distributions plot, we can say that,
#     * Modeling using multiple linear regression is far better than compared to simple linear regression.
#     * this is because overlapping area of Distributio plot between actual and predicted values is higher in case of multiple linear regression compalred to simple linear regression.

# %% [markdown]
# # Evaluation Techniques
# ### R square error
# ### Mean Squared Error
# ### Mean Absolute Error

# %%
# R square
data = y_test - y_pred
up = [item * item for item in data]
up
# Out:
# [980297.1844082493,
#  804644.8823356703,
#  3917430.223513047,
#  10642263.419912092,
#  15318758.738504764,
#  691304.2567275473,
#  36056905.25611268,
#  13694585.626886535,
#  10223423.731500912,
#  11290556.173485652,
#  2616870.3555560615,
#  10507367.120793061,
#  29745227.999386508,
#  29279987.221024934,
#  66571272.938296184,
#  5421304.924633721,
#  165632569.24100226,
#  36063955.090966344,
#  243298.7247298821,
#  5531328.096864264,
#  6518845.393699317,
#  5958057.862303883,
#  210667352.24538785,
#  11413381.053260282,
#  2626327.735573216,
#  81971298.3703771,
#  7311175.747811965,
#  62123900.61908697,
#  1845952.0681602946,
#  31.006510178676578,
#  7150252.149622105,
#  24974751.99677664,
#  7185951.537224619,
#  1307027.8918717867,
#  8626178.286088692,
#  766472.9614970697,
#  21434604.324184004,
#  13047874.369703203,
#  51433895.72269668,
#  180715514.65468007,
#  44866401.74455637]

# %%
below = y_test - y_test.mean()

# %%
r_square = 1 - (sum(up) / below.sum())
r_square
# Out:
# -1.3273069063453506e+20
