# %% [markdown]
# # Loading Datasets

# %%
import pandas as pd
import openpyxl
df = pd.read_excel("data/Data_Train.xlsx", engine="openpyxl")
df.sample(5)
# Out:
#                 Airline Date_of_Journey   Source Destination            Route  \
# 3511        Jet Airways      15/05/2019  Kolkata    Banglore  CCU → BOM → BLR
# 8832             IndiGo      21/03/2019    Delhi      Cochin  DEL → BOM → COK
# 8910  Multiple carriers      21/03/2019    Delhi      Cochin  DEL → BOM → COK
# 9082  Multiple carriers       3/06/2019    Delhi      Cochin  DEL → BOM → COK
# 3919        Jet Airways      24/03/2019  Kolkata    Banglore  CCU → BOM → BLR
#
#      Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 3511    14:05         23:35   9h 30m      1 stop                      No info
# 8832    04:45         15:30  10h 45m      1 stop                      No info
# 8910    10:45         19:15   8h 30m      1 stop                      No info
# 9082    19:00  01:30 04 Jun   6h 30m      1 stop                      No info
# 3919    06:30         12:00   5h 30m      1 stop  In-flight meal not included
#
#       Price
# 3511  13941
# 8832   7738
# 8910   7154
# 9082   7198
# 3919   7826

# %% [markdown]
# # Data inspection

# %%
df.shape # shape of the DataFrame (row, columns)
# Out:
# (10683, 11)

# %%
df.isnull().any() # checks if the DataFrame columns contains the null value of not
# Out:
# Airline            False
# Date_of_Journey    False
# Source             False
# Destination        False
# Route               True
# Dep_Time           False
# Arrival_Time       False
# Duration           False
# Total_Stops         True
# Additional_Info    False
# Price              False
# dtype: bool

# %%
df.isna().sum() # gives total number of missing values(null) in the columns
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df.isna().sum() / len(df) # gives percentage of the missing values of the columns
# Out:
# Airline            0.000000
# Date_of_Journey    0.000000
# Source             0.000000
# Destination        0.000000
# Route              0.000094
# Dep_Time           0.000000
# Arrival_Time       0.000000
# Duration           0.000000
# Total_Stops        0.000094
# Additional_Info    0.000000
# Price              0.000000
# dtype: float64

# %%
df.dropna(inplace=True) # since only 2 rows contains missing values so deleting the rows which contains the missing values
df.reset_index(inplace=True, drop=True)

# %%
df.isnull().any() # after deleting checking the missing value if there is any
# Out:
# Airline            False
# Date_of_Journey    False
# Source             False
# Destination        False
# Route              False
# Dep_Time           False
# Arrival_Time       False
# Duration           False
# Total_Stops        False
# Additional_Info    False
# Price              False
# dtype: bool

# %%
df.dtypes # checking the datatypes of all the columns
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
df.info() # checking the info of the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10682 entries, 0 to 10681
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10682 non-null  object
#  1   Date_of_Journey  10682 non-null  object
#  2   Source           10682 non-null  object
#  3   Destination      10682 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10682 non-null  object
#  6   Arrival_Time     10682 non-null  object
#  7   Duration         10682 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10682 non-null  object
#  10  Price            10682 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.1+ KB

# %%
df.describe() # overview of the numerical data
# Out:
#               Price
# count  10682.000000
# mean    9087.214567
# std     4611.548810
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
df.describe(include="object") # overview of the categorical data
# Out:
#             Airline Date_of_Journey Source Destination            Route  \
# count         10682           10682  10682       10682            10682
# unique           12              44      5           6              128
# top     Jet Airways      18/05/2019  Delhi      Cochin  DEL → BOM → COK
# freq           3849             504   4536        4536             2376
#
#        Dep_Time Arrival_Time Duration Total_Stops Additional_Info
# count     10682        10682    10682       10682           10682
# unique      222         1343      368           5              10
# top       18:55        19:00   2h 50m      1 stop         No info
# freq        233          423      550        5625            8344

# %%
df.sample(2)
# Out:
#           Airline Date_of_Journey   Source Destination            Route  \
# 2892  Jet Airways      21/05/2019    Delhi      Cochin  DEL → BOM → COK
# 7346       IndiGo      27/03/2019  Chennai     Kolkata        MAA → CCU
#
#      Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 2892    18:15  19:00 22 May  24h 45m      1 stop  In-flight meal not included
# 7346    13:20         15:35   2h 15m    non-stop                      No info
#
#       Price
# 2892  12898
# 7346   3384

# %%
day = []
month = []
for date in df["Date_of_Journey"]: # looping through date_of_journey to get day and month
    list_date = date.split("/") # splitting the date using "/" to get the form of ["9", "05", "2019"]
    day.append(list_date[0]) # appending 0 index data to day 
    month.append(list_date[1]) # appending 1 index data to month list

# month

# %%
df["Day"] = day # inserting day columns 
df["Month"] = month # inserting month columns in the dataframe

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  Day  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662    1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882    9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218   12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302    1
#
#    Month
# 0      3
# 1      5
# 2      6
# 3      5
# 4      3

# %%
df.drop("Date_of_Journey", axis=1, inplace=True) # deleting Date of journey columns form the dataframe

# %%
df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  Day  Month
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897   24      3
# 1         13:15   7h 25m     2 stops         No info   7662    1      5

# %%
# Extracting hour and minute from the Departure time (Dep_Time) from the dataframe and dumping it in new columns (Dep_Hour, Dep_Minute)
dep_hrs = []
dep_min = []
for time in df["Dep_Time"]:
    # print(time)
    list_time = time.split(":")
    # print(list_time)
    dep_hrs.append(list_time[0])
    dep_min.append(list_time[1])
# dep_hrs
# dep_min

# %%
# Adding columns Dep_Hours and Dep_Minute in the DataFrame
df["Dep_Hours"] = dep_hrs
df["Dep_Minutes"] = dep_min

# %%
df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  Day  Month  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897   24      3
# 1         13:15   7h 25m     2 stops         No info   7662    1      5
#
#    Dep_Hours  Dep_Minutes
# 0         22           20
# 1          5           50

# %%
# Deleting Dep_Time columns from the dataframe
df.drop("Dep_Time", axis="columns", inplace=True)
df.head(2)
# Out:
#      Airline    Source Destination                  Route  Arrival_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
#
#   Duration Total_Stops Additional_Info  Price  Day  Month  Dep_Hours  \
# 0   2h 50m    non-stop         No info   3897   24      3         22
# 1   7h 25m     2 stops         No info   7662    1      5          5
#
#    Dep_Minutes
# 0           20
# 1           50

# %%
df.dtypes
# Out:
# Airline            object
# Source             object
# Destination        object
# Route              object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# Day                 int64
# Month               int64
# Dep_Hours           int64
# Dep_Minutes         int64
# dtype: object

# %%
# Extracting hour and minute from the Arrival time (Arrival_Time) from the dataframe and dumping it in new columns (Arrival_Hour, Arrival_Minute)
df["Arrival_Hour"] = pd.DatetimeIndex(df["Arrival_Time"]).hour
df["Arrival_Minute"] = pd.DatetimeIndex(df["Arrival_Time"]).minute
df.drop("Arrival_Time", axis=1, inplace=True)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops Additional_Info  Price  Day  Month  Dep_Hours  Dep_Minutes  \
# 0    non-stop         No info   3897   24      3         22           20
# 1     2 stops         No info   7662    1      5          5           50
# 2     2 stops         No info  13882    9      6          9           25
# 3      1 stop         No info   6218   12      5         18            5
# 4      1 stop         No info  13302    1      3         16           50
#
#    Arrival_Hour  Arrival_Minute
# 0             1              10
# 1            13              15
# 2             4              25
# 3            23              30
# 4            21              35

# %%
td = pd.to_timedelta(df["Duration"])
td
# Out:
# 0       0 days 02:50:00
# 1       0 days 07:25:00
# 2       0 days 19:00:00
# 3       0 days 05:25:00
# 4       0 days 04:45:00
#               ...
# 10677   0 days 02:30:00
# 10678   0 days 02:35:00
# 10679   0 days 03:00:00
# 10680   0 days 02:40:00
# 10681   0 days 08:20:00
# Name: Duration, Length: 10682, dtype: timedelta64[ns]

# %%
dur_hr = []
dur_min = []
for i in range(len(td)):
    seconds = td[i].seconds
    minutes = seconds / 60
    hour = minutes // 60
    minute = minutes % 60
    dur_hr.append(hour)
    dur_min.append(minute)

dur_min[:5]
# Out:
# [50.0, 25.0, 0.0, 25.0, 45.0]

# %%
df["Duration_Hour"] = dur_hr
df["Duration_Minute"] = dur_min

# %%
df[["Duration_Hour", "Duration_Minute"]] = df[["Duration_Hour", "Duration_Minute"]].astype("int32")

# %%
df.head(2)
# Out:
#      Airline    Source Destination                  Route Duration  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
#
#   Total_Stops Additional_Info  Price  Day  Month  Dep_Hours  Dep_Minutes  \
# 0    non-stop         No info   3897   24      3         22           20
# 1     2 stops         No info   7662    1      5          5           50
#
#    Arrival_Hour  Arrival_Minute  Duration_Hour  Duration_Minute
# 0             1              10              2               50
# 1            13              15              7               25

# %%
df.dtypes
# Out:
# Airline            object
# Source             object
# Destination        object
# Route              object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# Day                 int64
# Month               int64
# Dep_Hours           int64
# Dep_Minutes         int64
# Arrival_Hour        int32
# Arrival_Minute      int32
# Duration_Hour       int32
# Duration_Minute     int32
# dtype: object
