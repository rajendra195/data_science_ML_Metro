# %% [markdown]
# # Loading Datasets

# %%
import pandas as pd
import openpyxl
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


df = pd.read_excel("data/Data_Train.xlsx", engine="openpyxl")
df.sample(5)
# Out:
#                 Airline Date_of_Journey   Source Destination  \
# 3175  Multiple carriers      27/03/2019    Delhi      Cochin
# 529           Air India      24/04/2019    Delhi      Cochin
# 2888        Jet Airways       3/05/2019   Mumbai   Hyderabad
# 2550        Jet Airways       3/06/2019    Delhi      Cochin
# 7346             IndiGo      27/03/2019  Chennai     Kolkata
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 3175        DEL → BOM → COK    12:50         21:00   8h 10m      1 stop
# 529               DEL → COK    05:10         08:00   2h 50m    non-stop
# 2888              BOM → HYD    10:20         11:50   1h 30m    non-stop
# 2550  DEL → NAG → BOM → COK    14:35  12:35 04 Jun      22h     2 stops
# 7346              MAA → CCU    13:20         15:35   2h 15m    non-stop
#
#                   Additional_Info  Price
# 3175                      No info   6637
# 529                       No info   5201
# 2888  In-flight meal not included   4995
# 2550                      No info  13376
# 7346                      No info   3384

# %% [markdown]
# # Data inspection

# %%
df.shape # shape of the DataFrame (row, columns)
# Out:
# (10683, 11)

# %%
df.isnull().any() # checks if the DataFrame columns contains the null value of not
# Out:
# Airline            False
# Date_of_Journey    False
# Source             False
# Destination        False
# Route               True
# Dep_Time           False
# Arrival_Time       False
# Duration           False
# Total_Stops         True
# Additional_Info    False
# Price              False
# dtype: bool

# %%
df.isna().sum() # gives total number of missing values(null) in the columns
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df.isna().sum() / len(df) # gives percentage of the missing values of the columns
# Out:
# Airline            0.000000
# Date_of_Journey    0.000000
# Source             0.000000
# Destination        0.000000
# Route              0.000094
# Dep_Time           0.000000
# Arrival_Time       0.000000
# Duration           0.000000
# Total_Stops        0.000094
# Additional_Info    0.000000
# Price              0.000000
# dtype: float64

# %%
df.dropna(inplace=True) # since only 2 rows contains missing values so deleting the rows which contains the missing values
df.reset_index(inplace=True, drop=True) # resetting index of the dataframe as index from the middle is dropped

# %%
df.isnull().any() # after deleting checking the missing value if there is any
# Out:
# Airline            False
# Date_of_Journey    False
# Source             False
# Destination        False
# Route              False
# Dep_Time           False
# Arrival_Time       False
# Duration           False
# Total_Stops        False
# Additional_Info    False
# Price              False
# dtype: bool

# %%
df.dtypes # checking the datatypes of all the columns
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
df.info() # checking the info of the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10682 entries, 0 to 10681
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10682 non-null  object
#  1   Date_of_Journey  10682 non-null  object
#  2   Source           10682 non-null  object
#  3   Destination      10682 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10682 non-null  object
#  6   Arrival_Time     10682 non-null  object
#  7   Duration         10682 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10682 non-null  object
#  10  Price            10682 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.1+ KB

# %%
df.describe() # overview of the numerical data
# Out:
#               Price
# count  10682.000000
# mean    9087.214567
# std     4611.548810
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
df.describe(include="object") # overview of the categorical data
# Out:
#             Airline Date_of_Journey Source Destination            Route  \
# count         10682           10682  10682       10682            10682
# unique           12              44      5           6              128
# top     Jet Airways      18/05/2019  Delhi      Cochin  DEL → BOM → COK
# freq           3849             504   4536        4536             2376
#
#        Dep_Time Arrival_Time Duration Total_Stops Additional_Info
# count     10682        10682    10682       10682           10682
# unique      222         1343      368           5              10
# top       18:55        19:00   2h 50m      1 stop         No info
# freq        233          423      550        5625            8344

# %%
df.sample(2)
# Out:
#           Airline Date_of_Journey   Source Destination            Route  \
# 6081  Jet Airways       9/03/2019    Delhi      Cochin  DEL → BOM → COK
# 1293     SpiceJet       6/06/2019  Chennai     Kolkata        MAA → CCU
#
#      Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 6081    20:50  18:50 10 Mar      22h      1 stop         No info  16289
# 1293    09:45         12:00   2h 15m    non-stop         No info   3597

# %%
day = []
month = []
for date in df["Date_of_Journey"]: # looping through date_of_journey to get day and month
    list_date = date.split("/") # splitting the date using "/" to get the form of ["9", "05", "2019"]
    day.append(list_date[0]) # appending 0 index data to day 
    month.append(list_date[1]) # appending 1 index data to month list

# month

# %%
df["Day"] = day # inserting day columns 
df["Month"] = month # inserting month columns in the dataframe

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price Day Month
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897  24    03
# 1    05:50         13:15   7h 25m     2 stops         No info   7662   1    05
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882   9    06
# 3    18:05         23:30   5h 25m      1 stop         No info   6218  12    05
# 4    16:50         21:35   4h 45m      1 stop         No info  13302  01    03

# %%
df.drop("Date_of_Journey", axis=1, inplace=True) # deleting Date of journey columns form the dataframe

# %%
df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price Day Month
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897  24    03
# 1         13:15   7h 25m     2 stops         No info   7662   1    05

# %%
# Extracting hour and minute from the Departure time (Dep_Time) from the dataframe and dumping it in new columns (Dep_Hour, Dep_Minute)
dep_hrs = []
dep_min = []
for time in df["Dep_Time"]:
    # print(time)
    list_time = time.split(":")
    # print(list_time)
    dep_hrs.append(list_time[0])
    dep_min.append(list_time[1])
# dep_hrs
# dep_min

# %%
# Adding columns Dep_Hours and Dep_Minute in the DataFrame
df["Dep_Hours"] = dep_hrs
df["Dep_Minutes"] = dep_min

# %%
df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price Day Month  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897  24    03
# 1         13:15   7h 25m     2 stops         No info   7662   1    05
#
#   Dep_Hours Dep_Minutes
# 0        22          20
# 1        05          50

# %%
# Deleting Dep_Time columns from the dataframe
df.drop("Dep_Time", axis="columns", inplace=True)
df.head(2)
# Out:
#      Airline    Source Destination                  Route  Arrival_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
#
#   Duration Total_Stops Additional_Info  Price Day Month Dep_Hours Dep_Minutes
# 0   2h 50m    non-stop         No info   3897  24    03        22          20
# 1   7h 25m     2 stops         No info   7662   1    05        05          50

# %%
df.dtypes
# Out:
# Airline            object
# Source             object
# Destination        object
# Route              object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# Day                object
# Month              object
# Dep_Hours          object
# Dep_Minutes        object
# dtype: object

# %%
# Extracting hour and minute from the Arrival time (Arrival_Time) from the dataframe and dumping it in new columns (Arrival_Hour, Arrival_Minute)
df["Arrival_Hour"] = pd.DatetimeIndex(df["Arrival_Time"]).hour
df["Arrival_Minute"] = pd.DatetimeIndex(df["Arrival_Time"]).minute
df.drop("Arrival_Time", axis=1, inplace=True)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops Additional_Info  Price Day Month Dep_Hours Dep_Minutes  \
# 0    non-stop         No info   3897  24    03        22          20
# 1     2 stops         No info   7662   1    05        05          50
# 2     2 stops         No info  13882   9    06        09          25
# 3      1 stop         No info   6218  12    05        18          05
# 4      1 stop         No info  13302  01    03        16          50
#
#    Arrival_Hour  Arrival_Minute
# 0             1              10
# 1            13              15
# 2             4              25
# 3            23              30
# 4            21              35

# %%
# converting Duration in the format with out alphabets 
td = pd.to_timedelta(df["Duration"])
td
# Out:
# 0       0 days 02:50:00
# 1       0 days 07:25:00
# 2       0 days 19:00:00
# 3       0 days 05:25:00
# 4       0 days 04:45:00
#               ...
# 10677   0 days 02:30:00
# 10678   0 days 02:35:00
# 10679   0 days 03:00:00
# 10680   0 days 02:40:00
# 10681   0 days 08:20:00
# Name: Duration, Length: 10682, dtype: timedelta64[ns]

# %%
# extracting duration hour and duration minute from the time delta(td)
dur_hr = []
dur_min = []
for i in range(len(td)): # loop using the length of timedelta
    seconds = td[i].seconds  # taking out the time in the format of seconds 
    minutes = seconds / 60  # total minutes in the duration
    hour = minutes // 60 #  # converting minutes in hours with the help of floor division
    minute = minutes % 60 # # minutes
    dur_hr.append(hour)  # appending the hour in duration hour list
    dur_min.append(minute) # appending the minute in duration minute list

dur_min[:5]
# Out:
# [50.0, 25.0, 0.0, 25.0, 45.0]

# %%
# Adding new column in the dataframe Duration_Hour and Duration_Minute
df["Duration_Hour"] = dur_hr
df["Duration_Minute"] = dur_min

# %%
# converting datatype of the columns in the int format using astype method
df[["Day", "Month", "Dep_Hours", "Dep_Minutes", "Duration_Hour", "Duration_Minute"]] = df[["Day", "Month", "Dep_Hours", "Dep_Minutes", "Duration_Hour", "Duration_Minute"]].astype("int32")

# %%
df.head(2)
# Out:
#      Airline    Source Destination                  Route Duration  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
#
#   Total_Stops Additional_Info  Price  Day  Month  Dep_Hours  Dep_Minutes  \
# 0    non-stop         No info   3897   24      3         22           20
# 1     2 stops         No info   7662    1      5          5           50
#
#    Arrival_Hour  Arrival_Minute  Duration_Hour  Duration_Minute
# 0             1              10              2               50
# 1            13              15              7               25

# %%
df.dtypes
# Out:
# Airline            object
# Source             object
# Destination        object
# Route              object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# Day                 int32
# Month               int32
# Dep_Hours           int32
# Dep_Minutes         int32
# Arrival_Hour        int32
# Arrival_Minute      int32
# Duration_Hour       int32
# Duration_Minute     int32
# dtype: object

# %%
# dropping Duration columns from the dataframe as hour and minute are already extracted from the duration
df.drop("Duration", axis=1, inplace=True)

# %%
df.head(2)
# Out:
#      Airline    Source Destination                  Route Total_Stops  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
#
#   Additional_Info  Price  Day  Month  Dep_Hours  Dep_Minutes  Arrival_Hour  \
# 0         No info   3897   24      3         22           20             1
# 1         No info   7662    1      5          5           50            13
#
#    Arrival_Minute  Duration_Hour  Duration_Minute
# 0              10              2               50
# 1              15              7               25

# %%
# extracting each route in a separate columns
l_route = [] # length of the route
routes = [] # total no. of the rutes in list of list

for i in range(len(df["Route"])): # looping through the length of the Route columns
    
    routes_n = [] # assigning empty value so that in the next iteration it should be empty
    item = df["Route"][i] # n item from the route column
    list = item.split("→") # splitting the item in the form of list
    # print(list)
    l_route.append(len(list)) #appending length of the list in the l_route list to get the length of the list

    for j in range(6): # looping 6 times to get 6 route (route_1 to route_6)
        
        if j < len(list): # if the value of j is less than length of list it will append the value in the list in the routes_n list
            routes_n.append(1) 
                    
        else:
            routes_n.append(0) # else if there is not value it will append "Nan"
            
    routes.append(routes_n) # appending routes into routes list to form list of list
                    
            
# routes
# l_route

# %%
# Adding new columns length of the route and all the route from route 1 to route 6 to the columns
df[["Route_1", "Route_2", "Route_3", "Route_4", "Route_5", "Route_6"]] = routes

# %%
# adding length_of_Route columns to the DataFrame
df["Length_of_Route"] = l_route

# %%
# dropping the route column after extracting each data
df.drop("Route", axis=1, inplace=True)

# %%
df.head(2)
# Out:
#      Airline    Source Destination Total_Stops Additional_Info  Price  Day  \
# 0     IndiGo  Banglore   New Delhi    non-stop         No info   3897   24
# 1  Air India   Kolkata    Banglore     2 stops         No info   7662    1
#
#    Month  Dep_Hours  Dep_Minutes  ...  Arrival_Minute  Duration_Hour  \
# 0      3         22           20  ...              10              2
# 1      5          5           50  ...              15              7
#
#    Duration_Minute  Route_1  Route_2  Route_3  Route_4  Route_5  Route_6  \
# 0               50        1        1        0        0        0        0
# 1               25        1        1        1        1        0        0
#
#    Length_of_Route
# 0                2
# 1                4
#
# [2 rows x 21 columns]

# %%
# REplacing categorical data of Total_stops with numerical value
df.replace(["non-stop", "1 stop", "2 stops", "3 stops", "4 stops"], [0, 1, 2, 3 ,4], inplace=True)
df.head()
# Out:
#        Airline    Source Destination  Total_Stops Additional_Info  Price  Day  \
# 0       IndiGo  Banglore   New Delhi            0         No info   3897   24
# 1    Air India   Kolkata    Banglore            2         No info   7662    1
# 2  Jet Airways     Delhi      Cochin            2         No info  13882    9
# 3       IndiGo   Kolkata    Banglore            1         No info   6218   12
# 4       IndiGo  Banglore   New Delhi            1         No info  13302    1
#
#    Month  Dep_Hours  Dep_Minutes  ...  Arrival_Minute  Duration_Hour  \
# 0      3         22           20  ...              10              2
# 1      5          5           50  ...              15              7
# 2      6          9           25  ...              25             19
# 3      5         18            5  ...              30              5
# 4      3         16           50  ...              35              4
#
#    Duration_Minute  Route_1  Route_2  Route_3  Route_4  Route_5  Route_6  \
# 0               50        1        1        0        0        0        0
# 1               25        1        1        1        1        0        0
# 2                0        1        1        1        1        0        0
# 3               25        1        1        1        0        0        0
# 4               45        1        1        1        0        0        0
#
#    Length_of_Route
# 0                2
# 1                4
# 2                4
# 3                3
# 4                3
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Since source, Destination, Airline and Additional_Info are nominal Data we use One Hot Encoding()

# %%
# performing one hot encoding in source and destinatio column
df = pd.get_dummies(data=df, columns=["Airline", "Source", "Destination", "Additional_Info"], drop_first=False, dtype="int")

# %%
df.head(2)
# Out:
#    Total_Stops  Price  Day  Month  Dep_Hours  Dep_Minutes  Arrival_Hour  \
# 0            0   3897   24      3         22           20             1
# 1            2   7662    1      5          5           50            13
#
#    Arrival_Minute  Duration_Hour  Duration_Minute  ...  \
# 0              10              2               50  ...
# 1              15              7               25  ...
#
#    Additional_Info_1 Long layover  Additional_Info_1 Short layover  \
# 0                               0                                0
# 1                               0                                0
#
#    Additional_Info_2 Long layover  Additional_Info_Business class  \
# 0                               0                               0
# 1                               0                               0
#
#    Additional_Info_Change airports  \
# 0                                0
# 1                                0
#
#    Additional_Info_In-flight meal not included  Additional_Info_No Info  \
# 0                                            0                        0
# 1                                            0                        0
#
#    Additional_Info_No check-in baggage included  Additional_Info_No info  \
# 0                                             0                        1
# 1                                             0                        1
#
#    Additional_Info_Red-eye flight
# 0                               0
# 1                               0
#
# [2 rows x 50 columns]

# %%
# Working with Total stops columns in the dataframe
# df["Total_Stops"].unique()
df.columns
# Out:
# Index(['Total_Stops', 'Price', 'Day', 'Month', 'Dep_Hours', 'Dep_Minutes',
#        'Arrival_Hour', 'Arrival_Minute', 'Duration_Hour', 'Duration_Minute',
#        'Route_1', 'Route_2', 'Route_3', 'Route_4', 'Route_5', 'Route_6',
#        'Length_of_Route', 'Airline_Air Asia', 'Airline_Air India',
#        'Airline_GoAir', 'Airline_IndiGo', 'Airline_Jet Airways',
#        'Airline_Jet Airways Business', 'Airline_Multiple carriers',
#        'Airline_Multiple carriers Premium economy', 'Airline_SpiceJet',
#        'Airline_Trujet', 'Airline_Vistara', 'Airline_Vistara Premium economy',
#        'Source_Banglore', 'Source_Chennai', 'Source_Delhi', 'Source_Kolkata',
#        'Source_Mumbai', 'Destination_Banglore', 'Destination_Cochin',
#        'Destination_Delhi', 'Destination_Hyderabad', 'Destination_Kolkata',
#        'Destination_New Delhi', 'Additional_Info_1 Long layover',
#        'Additional_Info_1 Short layover', 'Additional_Info_2 Long layover',
#        'Additional_Info_Business class', 'Additional_Info_Change airports',
#        'Additional_Info_In-flight meal not included',
#        'Additional_Info_No Info',
#        'Additional_Info_No check-in baggage included',
#        'Additional_Info_No info', 'Additional_Info_Red-eye flight'],
#       dtype='object')

# %%
df.isna().sum() / len(df)
# Out:
# Total_Stops                                     0.0
# Price                                           0.0
# Day                                             0.0
# Month                                           0.0
# Dep_Hours                                       0.0
# Dep_Minutes                                     0.0
# Arrival_Hour                                    0.0
# Arrival_Minute                                  0.0
# Duration_Hour                                   0.0
# Duration_Minute                                 0.0
# Route_1                                         0.0
# Route_2                                         0.0
# Route_3                                         0.0
# Route_4                                         0.0
# Route_5                                         0.0
# Route_6                                         0.0
# Length_of_Route                                 0.0
# Airline_Air Asia                                0.0
# Airline_Air India                               0.0
# Airline_GoAir                                   0.0
# Airline_IndiGo                                  0.0
# Airline_Jet Airways                             0.0
# Airline_Jet Airways Business                    0.0
# Airline_Multiple carriers                       0.0
# Airline_Multiple carriers Premium economy       0.0
# Airline_SpiceJet                                0.0
# Airline_Trujet                                  0.0
# Airline_Vistara                                 0.0
# Airline_Vistara Premium economy                 0.0
# Source_Banglore                                 0.0
# Source_Chennai                                  0.0
# Source_Delhi                                    0.0
# Source_Kolkata                                  0.0
# Source_Mumbai                                   0.0
# Destination_Banglore                            0.0
# Destination_Cochin                              0.0
# Destination_Delhi                               0.0
# Destination_Hyderabad                           0.0
# Destination_Kolkata                             0.0
# Destination_New Delhi                           0.0
# Additional_Info_1 Long layover                  0.0
# Additional_Info_1 Short layover                 0.0
# Additional_Info_2 Long layover                  0.0
# Additional_Info_Business class                  0.0
# Additional_Info_Change airports                 0.0
# Additional_Info_In-flight meal not included     0.0
# Additional_Info_No Info                         0.0
# Additional_Info_No check-in baggage included    0.0
# Additional_Info_No info                         0.0
# Additional_Info_Red-eye flight                  0.0
# dtype: float64

# %%
# mapping Total stops value with numerical values
# stop_mapping = {"non-stop": 0, "1 stop": 1, "2 stops": 2, "3 stops": 3, "4 stops": 4}
# df["Total_Stops"] = df["Total_Stops"].str.strip().map(stop_mapping)
# df.head(2)

# %%
# Checking total missing values
df.dtypes
# Out:
# Total_Stops                                     int64
# Price                                           int64
# Day                                             int32
# Month                                           int32
# Dep_Hours                                       int32
# Dep_Minutes                                     int32
# Arrival_Hour                                    int32
# Arrival_Minute                                  int32
# Duration_Hour                                   int32
# Duration_Minute                                 int32
# Route_1                                         int64
# Route_2                                         int64
# Route_3                                         int64
# Route_4                                         int64
# Route_5                                         int64
# Route_6                                         int64
# Length_of_Route                                 int64
# Airline_Air Asia                                int32
# Airline_Air India                               int32
# Airline_GoAir                                   int32
# Airline_IndiGo                                  int32
# Airline_Jet Airways                             int32
# Airline_Jet Airways Business                    int32
# Airline_Multiple carriers                       int32
# Airline_Multiple carriers Premium economy       int32
# Airline_SpiceJet                                int32
# Airline_Trujet                                  int32
# Airline_Vistara                                 int32
# Airline_Vistara Premium economy                 int32
# Source_Banglore                                 int32
# Source_Chennai                                  int32
# Source_Delhi                                    int32
# Source_Kolkata                                  int32
# Source_Mumbai                                   int32
# Destination_Banglore                            int32
# Destination_Cochin                              int32
# Destination_Delhi                               int32
# Destination_Hyderabad                           int32
# Destination_Kolkata                             int32
# Destination_New Delhi                           int32
# Additional_Info_1 Long layover                  int32
# Additional_Info_1 Short layover                 int32
# Additional_Info_2 Long layover                  int32
# Additional_Info_Business class                  int32
# Additional_Info_Change airports                 int32
# Additional_Info_In-flight meal not included     int32
# Additional_Info_No Info                         int32
# Additional_Info_No check-in baggage included    int32
# Additional_Info_No info                         int32
# Additional_Info_Red-eye flight                  int32
# dtype: object

# %%
df.shape
# Out:
# (10682, 50)

# %%
df_X = df[["Day", "Duration_Hour", "Length_of_Route", "Price", "Total_Stops", "Duration_Minute", "Route_3"]]
df_X
# Out:
#        Day  Duration_Hour  Length_of_Route  Price  Total_Stops  \
# 0       24              2                2   3897            0
# 1        1              7                4   7662            2
# 2        9             19                4  13882            2
# 3       12              5                3   6218            1
# 4        1              4                3  13302            1
# ...    ...            ...              ...    ...          ...
# 10677    9              2                2   4107            0
# 10678   27              2                2   4145            0
# 10679   27              3                2   7229            0
# 10680    1              2                2  12648            0
# 10681    9              8                4  11753            2
#
#        Duration_Minute  Route_3
# 0                   50        0
# 1                   25        1
# 2                    0        1
# 3                   25        1
# 4                   45        1
# ...                ...      ...
# 10677               30        0
# 10678               35        0
# 10679                0        0
# 10680               40        0
# 10681               20        1
#
# [10682 rows x 7 columns]

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
df_X.corr()
# Out:
#                       Day  Duration_Hour  Length_of_Route     Price  \
# Day              1.000000      -0.013416        -0.009451 -0.153774
# Duration_Hour   -0.013416       1.000000         0.594057  0.452643
# Length_of_Route -0.009451       0.594057         1.000000  0.603897
# Price           -0.153774       0.452643         0.603897  1.000000
# Total_Stops     -0.009451       0.594057         1.000000  0.603897
# Duration_Minute -0.008940      -0.149376        -0.136706 -0.124855
# Route_3         -0.025229       0.626549         0.850506  0.613801
#
#                  Total_Stops  Duration_Minute   Route_3
# Day                -0.009451        -0.008940 -0.025229
# Duration_Hour       0.594057        -0.149376  0.626549
# Length_of_Route     1.000000        -0.136706  0.850506
# Price               0.603897        -0.124855  0.613801
# Total_Stops         1.000000        -0.136706  0.850506
# Duration_Minute    -0.136706         1.000000 -0.179701
# Route_3             0.850506        -0.179701  1.000000

# %%
sns.heatmap(df_X.corr(), annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(14, 8))
sns.countplot(x="Length_of_Route", data=df)
plt.show()

# %%
df.groupby(["Total_Stops"], as_index=False).Price.mean()
# Out:
#    Total_Stops         Price
# 0            0   5024.900315
# 1            1  10594.123556
# 2            2  12715.807895
# 3            3  13112.000000
# 4            4  17686.000000

# %%
sns.countplot(x=df["Total_Stops"])
# Out:
# <Axes: xlabel='Total_Stops', ylabel='count'>

# %%
df.corr(numeric_only=True)
# Out:
#                                               Total_Stops     Price       Day  \
# Total_Stops                                      1.000000  0.603897 -0.009451
# Price                                            0.603897  1.000000 -0.153774
# Day                                             -0.009451 -0.153774  1.000000
# Month                                            0.054383 -0.103643 -0.038359
# Dep_Hours                                       -0.061476  0.006799  0.002170
# Dep_Minutes                                     -0.002618 -0.024458 -0.008170
# Arrival_Hour                                     0.038140  0.024244 -0.003245
# Arrival_Minute                                  -0.106940 -0.086155 -0.017510
# Duration_Hour                                    0.594057  0.452643 -0.013416
# Duration_Minute                                 -0.136706 -0.124855 -0.008940
# Route_1                                               NaN       NaN       NaN
# Route_2                                               NaN       NaN       NaN
# Route_3                                          0.850506  0.613801 -0.025229
# Route_4                                          0.740196  0.327450  0.017754
# Route_5                                          0.214041  0.058817 -0.010524
# Route_6                                          0.045511  0.018043 -0.014275
# Length_of_Route                                  1.000000  0.603897 -0.009451
# Airline_Air Asia                                -0.094423 -0.133050  0.008926
# Airline_Air India                                0.271094  0.050432 -0.032490
# Airline_GoAir                                   -0.060110 -0.095151 -0.003122
# Airline_IndiGo                                  -0.302991 -0.361070  0.007281
# Airline_Jet Airways                              0.215063  0.416124 -0.017304
# Airline_Jet Airways Business                     0.017876  0.253303 -0.031713
# Airline_Multiple carriers                        0.118399  0.139793  0.042163
# Airline_Multiple carriers Premium economy        0.009089  0.017650  0.030839
# Airline_SpiceJet                                -0.274351 -0.296565  0.022154
# Airline_Trujet                                   0.002519 -0.010381 -0.008569
# Airline_Vistara                                 -0.120447 -0.060654 -0.013169
# Airline_Vistara Premium economy                 -0.020459 -0.000454 -0.020115
# Source_Banglore                                 -0.368324 -0.118044 -0.050438
# Source_Chennai                                  -0.234758 -0.179223  0.006611
# Source_Delhi                                     0.490170  0.270676  0.100088
# Source_Kolkata                                   0.032761  0.009358 -0.060558
# Source_Mumbai                                   -0.260752 -0.230755 -0.014030
# Destination_Banglore                             0.032761  0.009358 -0.060558
# Destination_Cochin                               0.490170  0.270676  0.100088
# Destination_Delhi                               -0.447390 -0.313417  0.002632
# Destination_Hyderabad                           -0.260752 -0.230755 -0.014030
# Destination_Kolkata                             -0.234758 -0.179223  0.006611
# Destination_New Delhi                           -0.015302  0.189777 -0.075254
# Additional_Info_1 Long layover                   0.010991  0.119207 -0.056249
# Additional_Info_1 Short layover                  0.016850  0.037047 -0.014275
# Additional_Info_2 Long layover                   0.016850  0.036495 -0.014275
# Additional_Info_Business class                   0.005040  0.200307 -0.028554
# Additional_Info_Change airports                  0.044594  0.042834 -0.037779
# Additional_Info_In-flight meal not included      0.105734  0.039810  0.036156
# Additional_Info_No Info                          0.004364 -0.003789 -0.024727
# Additional_Info_No check-in baggage included    -0.201498 -0.207391  0.033426
# Additional_Info_No info                         -0.021140  0.022247 -0.036362
# Additional_Info_Red-eye flight                  -0.011811  0.003747 -0.014275
#
#                                                  Month  Dep_Hours  \
# Total_Stops                                   0.054383  -0.061476
# Price                                        -0.103643   0.006799
# Day                                          -0.038359   0.002170
# Month                                         1.000000   0.039127
# Dep_Hours                                     0.039127   1.000000
# Dep_Minutes                                  -0.059267  -0.024745
# Arrival_Hour                                 -0.003927   0.005180
# Arrival_Minute                               -0.100626   0.067911
# Duration_Hour                                 0.046494   0.011526
# Duration_Minute                              -0.040897  -0.023707
# Route_1                                            NaN        NaN
# Route_2                                            NaN        NaN
# Route_3                                       0.035934  -0.047908
# Route_4                                       0.058048  -0.044564
# Route_5                                      -0.008097  -0.048145
# Route_6                                      -0.014199  -0.012609
# Length_of_Route                               0.054383  -0.061476
# Airline_Air Asia                              0.005652   0.045960
# Airline_Air India                            -0.045981  -0.012879
# Airline_GoAir                                -0.004494  -0.016373
# Airline_IndiGo                               -0.048504  -0.023395
# Airline_Jet Airways                           0.059735   0.113942
# Airline_Jet Airways Business                 -0.034787  -0.007524
# Airline_Multiple carriers                     0.053685  -0.149992
# Airline_Multiple carriers Premium economy    -0.051222  -0.028672
# Airline_SpiceJet                             -0.011977  -0.010451
# Airline_Trujet                               -0.014199   0.000857
# Airline_Vistara                              -0.017252   0.023906
# Airline_Vistara Premium economy              -0.019797  -0.003375
# Source_Banglore                              -0.244418  -0.007887
# Source_Chennai                                0.005650  -0.014846
# Source_Delhi                                  0.139222  -0.118780
# Source_Kolkata                                0.087177   0.155471
# Source_Mumbai                                -0.039352  -0.017292
# Destination_Banglore                          0.087177   0.155471
# Destination_Cochin                            0.139222  -0.118780
# Destination_Delhi                             0.090490   0.009469
# Destination_Hyderabad                        -0.039352  -0.017292
# Destination_Kolkata                           0.005650  -0.014846
# Destination_New Delhi                        -0.453685  -0.022138
# Additional_Info_1 Long layover               -0.056218   0.003351
# Additional_Info_1 Short layover              -0.014199  -0.007559
# Additional_Info_2 Long layover               -0.014199  -0.010926
# Additional_Info_Business class               -0.028401  -0.021854
# Additional_Info_Change airports              -0.037576  -0.011733
# Additional_Info_In-flight meal not included   0.075616   0.057594
# Additional_Info_No Info                      -0.024595  -0.000460
# Additional_Info_No check-in baggage included  0.013799  -0.010234
# Additional_Info_No info                      -0.065403  -0.048484
# Additional_Info_Red-eye flight               -0.014199   0.017689
#
#                                               Dep_Minutes  Arrival_Hour  \
# Total_Stops                                     -0.002618      0.038140
# Price                                           -0.024458      0.024244
# Day                                             -0.008170     -0.003245
# Month                                           -0.059267     -0.003927
# Dep_Hours                                       -0.024745      0.005180
# Dep_Minutes                                      1.000000      0.043122
# Arrival_Hour                                     0.043122      1.000000
# Arrival_Minute                                  -0.017597     -0.154363
# Duration_Hour                                   -0.025085     -0.012782
# Duration_Minute                                  0.092485     -0.118309
# Route_1                                               NaN           NaN
# Route_2                                               NaN           NaN
# Route_3                                         -0.038416      0.084648
# Route_4                                          0.045976     -0.043982
# Route_5                                         -0.002120      0.024999
# Route_6                                          0.013194     -0.003314
# Length_of_Route                                 -0.002618      0.038140
# Airline_Air Asia                                 0.158211     -0.034993
# Airline_Air India                               -0.045688      0.088872
# Airline_GoAir                                    0.076751      0.018526
# Airline_IndiGo                                  -0.014714     -0.071491
# Airline_Jet Airways                              0.024455     -0.027377
# Airline_Jet Airways Business                     0.009168     -0.014456
# Airline_Multiple carriers                       -0.109370      0.067930
# Airline_Multiple carriers Premium economy       -0.004624      0.013491
# Airline_SpiceJet                                 0.092634     -0.090058
# Airline_Trujet                                  -0.010007      0.003739
# Airline_Vistara                                 -0.077903      0.068834
# Airline_Vistara Premium economy                 -0.011380      0.000776
# Source_Banglore                                  0.077354     -0.024419
# Source_Chennai                                   0.067110     -0.014795
# Source_Delhi                                    -0.085534     -0.006790
# Source_Kolkata                                  -0.024238      0.054693
# Source_Mumbai                                    0.037705     -0.033512
# Destination_Banglore                            -0.024238      0.054693
# Destination_Cochin                              -0.085534     -0.006790
# Destination_Delhi                                0.003200     -0.030867
# Destination_Hyderabad                            0.037705     -0.033512
# Destination_Kolkata                              0.067110     -0.014795
# Destination_New Delhi                            0.107129      0.000366
# Additional_Info_1 Long layover                   0.029149     -0.000529
# Additional_Info_1 Short layover                  0.013194      0.013614
# Additional_Info_2 Long layover                   0.010616     -0.006135
# Additional_Info_Business class                   0.022525     -0.003102
# Additional_Info_Change airports                  0.012502      0.021630
# Additional_Info_In-flight meal not included     -0.001658     -0.016821
# Additional_Info_No Info                          0.003505      0.008921
# Additional_Info_No check-in baggage included     0.062008     -0.087730
# Additional_Info_No info                         -0.029510      0.050682
# Additional_Info_Red-eye flight                   0.000305     -0.016010
#
#                                               Arrival_Minute  Duration_Hour  \
# Total_Stops                                        -0.106940       0.594057
# Price                                              -0.086155       0.452643
# Day                                                -0.017510      -0.013416
# Month                                              -0.100626       0.046494
# Dep_Hours                                           0.067911       0.011526
# Dep_Minutes                                        -0.017597      -0.025085
# Arrival_Hour                                       -0.154363      -0.012782
# Arrival_Minute                                      1.000000      -0.128140
# Duration_Hour                                      -0.128140       1.000000
# Duration_Minute                                     0.151628      -0.149376
# Route_1                                                  NaN            NaN
# Route_2                                                  NaN            NaN
# Route_3                                            -0.166323       0.626549
# Route_4                                             0.019955       0.299194
# Route_5                                            -0.018689       0.021936
# Route_6                                            -0.002750      -0.004113
# Length_of_Route                                    -0.106940       0.594057
# Airline_Air Asia                                    0.078261      -0.069268
# Airline_Air India                                   0.061231       0.094447
# Airline_GoAir                                       0.096839      -0.071138
# Airline_IndiGo                                      0.035124      -0.266971
# Airline_Jet Airways                                -0.057698       0.272796
# Airline_Jet Airways Business                        0.005232      -0.006384
# Airline_Multiple carriers                          -0.167455       0.128522
# Airline_Multiple carriers Premium economy          -0.001786       0.010679
# Airline_SpiceJet                                    0.012543      -0.236270
# Airline_Trujet                                     -0.002750      -0.007128
# Airline_Vistara                                     0.069422      -0.082378
# Airline_Vistara Premium economy                     0.000314      -0.014958
# Source_Banglore                                     0.090993      -0.247874
# Source_Chennai                                     -0.030493      -0.171636
# Source_Delhi                                       -0.209882       0.340543
# Source_Kolkata                                      0.118573       0.050579
# Source_Mumbai                                       0.081196      -0.237800
# Destination_Banglore                                0.118573       0.050579
# Destination_Cochin                                 -0.209882       0.340543
# Destination_Delhi                                   0.095250      -0.314457
# Destination_Hyderabad                               0.081196      -0.237800
# Destination_Kolkata                                -0.030493      -0.171636
# Destination_New Delhi                               0.021271       0.005014
# Additional_Info_1 Long layover                      0.009540       0.038820
# Additional_Info_1 Short layover                     0.000181       0.009454
# Additional_Info_2 Long layover                      0.000181      -0.008635
# Additional_Info_Business class                     -0.001103      -0.007473
# Additional_Info_Change airports                     0.001588       0.004503
# Additional_Info_In-flight meal not included        -0.045619       0.175810
# Additional_Info_No Info                             0.003699      -0.009736
# Additional_Info_No check-in baggage included       -0.002695      -0.158716
# Additional_Info_No info                             0.043024      -0.103162
# Additional_Info_Red-eye flight                     -0.008612      -0.008635
#
#                                               Duration_Minute  ...  \
# Total_Stops                                         -0.136706  ...
# Price                                               -0.124855  ...
# Day                                                 -0.008940  ...
# Month                                               -0.040897  ...
# Dep_Hours                                           -0.023707  ...
# Dep_Minutes                                          0.092485  ...
# Arrival_Hour                                        -0.118309  ...
# Arrival_Minute                                       0.151628  ...
# Duration_Hour                                       -0.149376  ...
# Duration_Minute                                      1.000000  ...
# Route_1                                                   NaN  ...
# Route_2                                                   NaN  ...
# Route_3                                             -0.179701  ...
# Route_4                                             -0.017408  ...
# Route_5                                             -0.028519  ...
# Route_6                                              0.000956  ...
# Length_of_Route                                     -0.136706  ...
# Airline_Air Asia                                     0.085812  ...
# Airline_Air India                                   -0.033427  ...
# Airline_GoAir                                        0.067215  ...
# Airline_IndiGo                                       0.119817  ...
# Airline_Jet Airways                                 -0.084052  ...
# Airline_Jet Airways Business                        -0.002322  ...
# Airline_Multiple carriers                           -0.118766  ...
# Airline_Multiple carriers Premium economy           -0.006853  ...
# Airline_SpiceJet                                     0.041319  ...
# Airline_Trujet                                      -0.007610  ...
# Airline_Vistara                                      0.041952  ...
# Airline_Vistara Premium economy                      0.004952  ...
# Source_Banglore                                      0.230195  ...
# Source_Chennai                                      -0.098823  ...
# Source_Delhi                                        -0.154126  ...
# Source_Kolkata                                       0.013761  ...
# Source_Mumbai                                       -0.018761  ...
# Destination_Banglore                                 0.013761  ...
# Destination_Cochin                                  -0.154126  ...
# Destination_Delhi                                    0.218207  ...
# Destination_Hyderabad                               -0.018761  ...
# Destination_Kolkata                                 -0.098823  ...
# Destination_New Delhi                                0.079866  ...
# Additional_Info_1 Long layover                      -0.006320  ...
# Additional_Info_1 Short layover                      0.003811  ...
# Additional_Info_2 Long layover                       0.006666  ...
# Additional_Info_Business class                       0.010478  ...
# Additional_Info_Change airports                     -0.015822  ...
# Additional_Info_In-flight meal not included         -0.052347  ...
# Additional_Info_No Info                              0.011546  ...
# Additional_Info_No check-in baggage included         0.034531  ...
# Additional_Info_No info                              0.035176  ...
# Additional_Info_Red-eye flight                       0.009521  ...
#
#                                               Additional_Info_1 Long layover  \
# Total_Stops                                                         0.010991
# Price                                                               0.119207
# Day                                                                -0.056249
# Month                                                              -0.056218
# Dep_Hours                                                           0.003351
# Dep_Minutes                                                         0.029149
# Arrival_Hour                                                       -0.000529
# Arrival_Minute                                                      0.009540
# Duration_Hour                                                       0.038820
# Duration_Minute                                                    -0.006320
# Route_1                                                                  NaN
# Route_2                                                                  NaN
# Route_3                                                             0.029412
# Route_4                                                            -0.017496
# Route_5                                                            -0.002776
# Route_6                                                            -0.000408
# Length_of_Route                                                     0.010991
# Airline_Air Asia                                                   -0.007406
# Airline_Air India                                                   0.017317
# Airline_GoAir                                                      -0.005741
# Airline_IndiGo                                                     -0.020590
# Airline_Jet Airways                                                 0.023850
# Airline_Jet Airways Business                                       -0.001001
# Airline_Multiple carriers                                          -0.014989
# Airline_Multiple carriers Premium economy                          -0.001473
# Airline_SpiceJet                                                   -0.003801
# Airline_Trujet                                                     -0.000408
# Airline_Vistara                                                    -0.009146
# Airline_Vistara Premium economy                                    -0.000708
# Source_Banglore                                                     0.077459
# Source_Chennai                                                     -0.008118
# Source_Delhi                                                       -0.031769
# Source_Kolkata                                                     -0.025592
# Source_Mumbai                                                      -0.011153
# Destination_Banglore                                               -0.025592
# Destination_Cochin                                                 -0.031769
# Destination_Delhi                                                  -0.015471
# Destination_Hyderabad                                              -0.011153
# Destination_Kolkata                                                -0.008118
# Destination_New Delhi                                               0.128658
# Additional_Info_1 Long layover                                      1.000000
# Additional_Info_1 Short layover                                    -0.000408
# Additional_Info_2 Long layover                                     -0.000408
# Additional_Info_Business class                                     -0.000817
# Additional_Info_Change airports                                    -0.001081
# Additional_Info_In-flight meal not included                        -0.020148
# Additional_Info_No Info                                            -0.000708
# Additional_Info_No check-in baggage included                       -0.007418
# Additional_Info_No info                                            -0.079745
# Additional_Info_Red-eye flight                                     -0.000408
#
#                                               Additional_Info_1 Short layover  \
# Total_Stops                                                          0.016850
# Price                                                                0.037047
# Day                                                                 -0.014275
# Month                                                               -0.014199
# Dep_Hours                                                           -0.007559
# Dep_Minutes                                                          0.013194
# Arrival_Hour                                                         0.013614
# Arrival_Minute                                                       0.000181
# Duration_Hour                                                        0.009454
# Duration_Minute                                                      0.003811
# Route_1                                                                   NaN
# Route_2                                                                   NaN
# Route_3                                                              0.006742
# Route_4                                                              0.023345
# Route_5                                                             -0.000636
# Route_6                                                             -0.000094
# Length_of_Route                                                      0.016850
# Airline_Air Asia                                                    -0.001698
# Airline_Air India                                                    0.021852
# Airline_GoAir                                                       -0.001316
# Airline_IndiGo                                                      -0.004720
# Airline_Jet Airways                                                 -0.007262
# Airline_Jet Airways Business                                        -0.000229
# Airline_Multiple carriers                                           -0.003436
# Airline_Multiple carriers Premium economy                           -0.000338
# Airline_SpiceJet                                                    -0.002786
# Airline_Trujet                                                      -0.000094
# Airline_Vistara                                                     -0.002097
# Airline_Vistara Premium economy                                     -0.000162
# Source_Banglore                                                      0.019015
# Source_Chennai                                                      -0.001861
# Source_Delhi                                                        -0.008313
# Source_Kolkata                                                      -0.005866
# Source_Mumbai                                                       -0.002556
# Destination_Banglore                                                -0.005866
# Destination_Cochin                                                  -0.008313
# Destination_Delhi                                                   -0.003546
# Destination_Hyderabad                                               -0.002556
# Destination_Kolkata                                                 -0.001861
# Destination_New Delhi                                                0.031296
# Additional_Info_1 Long layover                                      -0.000408
# Additional_Info_1 Short layover                                      1.000000
# Additional_Info_2 Long layover                                      -0.000094
# Additional_Info_Business class                                      -0.000187
# Additional_Info_Change airports                                     -0.000248
# Additional_Info_In-flight meal not included                         -0.004618
# Additional_Info_No Info                                             -0.000162
# Additional_Info_No check-in baggage included                        -0.001700
# Additional_Info_No info                                             -0.018279
# Additional_Info_Red-eye flight                                      -0.000094
#
#                                               Additional_Info_2 Long layover  \
# Total_Stops                                                         0.016850
# Price                                                               0.036495
# Day                                                                -0.014275
# Month                                                              -0.014199
# Dep_Hours                                                          -0.010926
# Dep_Minutes                                                         0.010616
# Arrival_Hour                                                       -0.006135
# Arrival_Minute                                                      0.000181
# Duration_Hour                                                      -0.008635
# Duration_Minute                                                     0.006666
# Route_1                                                                  NaN
# Route_2                                                                  NaN
# Route_3                                                             0.006742
# Route_4                                                             0.023345
# Route_5                                                            -0.000636
# Route_6                                                            -0.000094
# Length_of_Route                                                     0.016850
# Airline_Air Asia                                                   -0.001698
# Airline_Air India                                                   0.021852
# Airline_GoAir                                                      -0.001316
# Airline_IndiGo                                                     -0.004720
# Airline_Jet Airways                                                -0.007262
# Airline_Jet Airways Business                                       -0.000229
# Airline_Multiple carriers                                          -0.003436
# Airline_Multiple carriers Premium economy                          -0.000338
# Airline_SpiceJet                                                   -0.002786
# Airline_Trujet                                                     -0.000094
# Airline_Vistara                                                    -0.002097
# Airline_Vistara Premium economy                                    -0.000162
# Source_Banglore                                                     0.019015
# Source_Chennai                                                     -0.001861
# Source_Delhi                                                       -0.008313
# Source_Kolkata                                                     -0.005866
# Source_Mumbai                                                      -0.002556
# Destination_Banglore                                               -0.005866
# Destination_Cochin                                                 -0.008313
# Destination_Delhi                                                  -0.003546
# Destination_Hyderabad                                              -0.002556
# Destination_Kolkata                                                -0.001861
# Destination_New Delhi                                               0.031296
# Additional_Info_1 Long layover                                     -0.000408
# Additional_Info_1 Short layover                                    -0.000094
# Additional_Info_2 Long layover                                      1.000000
# Additional_Info_Business class                                     -0.000187
# Additional_Info_Change airports                                    -0.000248
# Additional_Info_In-flight meal not included                        -0.004618
# Additional_Info_No Info                                            -0.000162
# Additional_Info_No check-in baggage included                       -0.001700
# Additional_Info_No info                                            -0.018279
# Additional_Info_Red-eye flight                                     -0.000094
#
#                                               Additional_Info_Business class  \
# Total_Stops                                                         0.005040
# Price                                                               0.200307
# Day                                                                -0.028554
# Month                                                              -0.028401
# Dep_Hours                                                          -0.021854
# Dep_Minutes                                                         0.022525
# Arrival_Hour                                                       -0.003102
# Arrival_Minute                                                     -0.001103
# Duration_Hour                                                      -0.007473
# Duration_Minute                                                     0.010478
# Route_1                                                                  NaN
# Route_2                                                                  NaN
# Route_3                                                             0.013485
# Route_4                                                            -0.008022
# Route_5                                                            -0.001273
# Route_6                                                            -0.000187
# Length_of_Route                                                     0.005040
# Airline_Air Asia                                                   -0.003396
# Airline_Air India                                                  -0.008570
# Airline_GoAir                                                      -0.002632
# Airline_IndiGo                                                     -0.009441
# Airline_Jet Airways                                                -0.004448
# Airline_Jet Airways Business                                        0.612200
# Airline_Multiple carriers                                          -0.006872
# Airline_Multiple carriers Premium economy                          -0.000676
# Airline_SpiceJet                                                   -0.005574
# Airline_Trujet                                                     -0.000187
# Airline_Vistara                                                    -0.004194
# Airline_Vistara Premium economy                                    -0.000324
# Source_Banglore                                                     0.038036
# Source_Chennai                                                     -0.003722
# Source_Delhi                                                       -0.016627
# Source_Kolkata                                                     -0.011734
# Source_Mumbai                                                      -0.005114
# Destination_Banglore                                               -0.011734
# Destination_Cochin                                                 -0.016627
# Destination_Delhi                                                  -0.007094
# Destination_Hyderabad                                              -0.005114
# Destination_Kolkata                                                -0.003722
# Destination_New Delhi                                               0.062601
# Additional_Info_1 Long layover                                     -0.000817
# Additional_Info_1 Short layover                                    -0.000187
# Additional_Info_2 Long layover                                     -0.000187
# Additional_Info_Business class                                      1.000000
# Additional_Info_Change airports                                    -0.000496
# Additional_Info_In-flight meal not included                        -0.009238
# Additional_Info_No Info                                            -0.000324
# Additional_Info_No check-in baggage included                       -0.003401
# Additional_Info_No info                                            -0.036564
# Additional_Info_Red-eye flight                                     -0.000187
#
#                                               Additional_Info_Change airports  \
# Total_Stops                                                          0.044594
# Price                                                                0.042834
# Day                                                                 -0.037779
# Month                                                               -0.037576
# Dep_Hours                                                           -0.011733
# Dep_Minutes                                                          0.012502
# Arrival_Hour                                                         0.021630
# Arrival_Minute                                                       0.001588
# Duration_Hour                                                        0.004503
# Duration_Minute                                                     -0.015822
# Route_1                                                                   NaN
# Route_2                                                                   NaN
# Route_3                                                              0.017842
# Route_4                                                              0.041099
# Route_5                                                              0.054182
# Route_6                                                              0.377858
# Length_of_Route                                                      0.044594
# Airline_Air Asia                                                    -0.004493
# Airline_Air India                                                    0.057833
# Airline_GoAir                                                       -0.003483
# Airline_IndiGo                                                      -0.012490
# Airline_Jet Airways                                                 -0.019219
# Airline_Jet Airways Business                                        -0.000607
# Airline_Multiple carriers                                           -0.009093
# Airline_Multiple carriers Premium economy                           -0.000894
# Airline_SpiceJet                                                    -0.007374
# Airline_Trujet                                                      -0.000248
# Airline_Vistara                                                     -0.005548
# Airline_Vistara Premium economy                                     -0.000429
# Source_Banglore                                                      0.050324
# Source_Chennai                                                      -0.004925
# Source_Delhi                                                        -0.021999
# Source_Kolkata                                                      -0.015525
# Source_Mumbai                                                       -0.006766
# Destination_Banglore                                                -0.015525
# Destination_Cochin                                                  -0.021999
# Destination_Delhi                                                   -0.009385
# Destination_Hyderabad                                               -0.006766
# Destination_Kolkata                                                 -0.004925
# Destination_New Delhi                                                0.082825
# Additional_Info_1 Long layover                                      -0.001081
# Additional_Info_1 Short layover                                     -0.000248
# Additional_Info_2 Long layover                                      -0.000248
# Additional_Info_Business class                                      -0.000496
# Additional_Info_Change airports                                      1.000000
# Additional_Info_In-flight meal not included                         -0.012222
# Additional_Info_No Info                                             -0.000429
# Additional_Info_No check-in baggage included                        -0.004500
# Additional_Info_No info                                             -0.048376
# Additional_Info_Red-eye flight                                      -0.000248
#
#                                               Additional_Info_In-flight meal not included  \
# Total_Stops                                                                      0.105734
# Price                                                                            0.039810
# Day                                                                              0.036156
# Month                                                                            0.075616
# Dep_Hours                                                                        0.057594
# Dep_Minutes                                                                     -0.001658
# Arrival_Hour                                                                    -0.016821
# Arrival_Minute                                                                  -0.045619
# Duration_Hour                                                                    0.175810
# Duration_Minute                                                                 -0.052347
# Route_1                                                                               NaN
# Route_2                                                                               NaN
# Route_3                                                                          0.178023
# Route_4                                                                         -0.028299
# Route_5                                                                         -0.031389
# Route_6                                                                         -0.004618
# Length_of_Route                                                                  0.105734
# Airline_Air Asia                                                                -0.083742
# Airline_Air India                                                               -0.211342
# Airline_GoAir                                                                   -0.064915
# Airline_IndiGo                                                                  -0.232813
# Airline_Jet Airways                                                              0.587797
# Airline_Jet Airways Business                                                    -0.011315
# Airline_Multiple carriers                                                       -0.096162
# Airline_Multiple carriers Premium economy                                       -0.016661
# Airline_SpiceJet                                                                -0.137449
# Airline_Trujet                                                                  -0.004618
# Airline_Vistara                                                                 -0.103418
# Airline_Vistara Premium economy                                                 -0.008000
# Source_Banglore                                                                 -0.039111
# Source_Chennai                                                                  -0.091794
# Source_Delhi                                                                     0.032333
# Source_Kolkata                                                                   0.053940
# Source_Mumbai                                                                   -0.028595
# Destination_Banglore                                                             0.053940
# Destination_Cochin                                                               0.032333
# Destination_Delhi                                                               -0.040035
# Destination_Hyderabad                                                           -0.028595
# Destination_Kolkata                                                             -0.091794
# Destination_New Delhi                                                           -0.010179
# Additional_Info_1 Long layover                                                  -0.020148
# Additional_Info_1 Short layover                                                 -0.004618
# Additional_Info_2 Long layover                                                  -0.004618
# Additional_Info_Business class                                                  -0.009238
# Additional_Info_Change airports                                                 -0.012222
# Additional_Info_In-flight meal not included                                      1.000000
# Additional_Info_No Info                                                         -0.008000
# Additional_Info_No check-in baggage included                                    -0.083877
# Additional_Info_No info                                                         -0.901690
# Additional_Info_Red-eye flight                                                  -0.004618
#
#                                               Additional_Info_No Info  \
# Total_Stops                                                  0.004364
# Price                                                       -0.003789
# Day                                                         -0.024727
# Month                                                       -0.024595
# Dep_Hours                                                   -0.000460
# Dep_Minutes                                                  0.003505
# Arrival_Hour                                                 0.008921
# Arrival_Minute                                               0.003699
# Duration_Hour                                               -0.009736
# Duration_Minute                                              0.011546
# Route_1                                                           NaN
# Route_2                                                           NaN
# Route_3                                                      0.011678
# Route_4                                                     -0.006947
# Route_5                                                     -0.001102
# Route_6                                                     -0.000162
# Length_of_Route                                              0.004364
# Airline_Air Asia                                            -0.002941
# Airline_Air India                                           -0.007421
# Airline_GoAir                                               -0.002280
# Airline_IndiGo                                               0.034362
# Airline_Jet Airways                                         -0.012580
# Airline_Jet Airways Business                                -0.000397
# Airline_Multiple carriers                                   -0.005951
# Airline_Multiple carriers Premium economy                   -0.000585
# Airline_SpiceJet                                            -0.004827
# Airline_Trujet                                              -0.000162
# Airline_Vistara                                             -0.003632
# Airline_Vistara Premium economy                             -0.000281
# Source_Banglore                                              0.032939
# Source_Chennai                                              -0.003223
# Source_Delhi                                                -0.014399
# Source_Kolkata                                              -0.010162
# Source_Mumbai                                               -0.004428
# Destination_Banglore                                        -0.010162
# Destination_Cochin                                          -0.014399
# Destination_Delhi                                           -0.006143
# Destination_Hyderabad                                       -0.004428
# Destination_Kolkata                                         -0.003223
# Destination_New Delhi                                        0.054211
# Additional_Info_1 Long layover                              -0.000708
# Additional_Info_1 Short layover                             -0.000162
# Additional_Info_2 Long layover                              -0.000162
# Additional_Info_Business class                              -0.000324
# Additional_Info_Change airports                             -0.000429
# Additional_Info_In-flight meal not included                 -0.008000
# Additional_Info_No Info                                      1.000000
# Additional_Info_No check-in baggage included                -0.002945
# Additional_Info_No info                                     -0.031664
# Additional_Info_Red-eye flight                              -0.000162
#
#                                               Additional_Info_No check-in baggage included  \
# Total_Stops                                                                      -0.201498
# Price                                                                            -0.207391
# Day                                                                               0.033426
# Month                                                                             0.013799
# Dep_Hours                                                                        -0.010234
# Dep_Minutes                                                                       0.062008
# Arrival_Hour                                                                     -0.087730
# Arrival_Minute                                                                   -0.002695
# Duration_Hour                                                                    -0.158716
# Duration_Minute                                                                   0.034531
# Route_1                                                                                NaN
# Route_2                                                                                NaN
# Route_3                                                                          -0.233483
# Route_4                                                                          -0.072836
# Route_5                                                                          -0.011557
# Route_6                                                                          -0.001700
# Length_of_Route                                                                  -0.201498
# Airline_Air Asia                                                                 -0.030832
# Airline_Air India                                                                -0.077812
# Airline_GoAir                                                                    -0.023901
# Airline_IndiGo                                                                   -0.085717
# Airline_Jet Airways                                                              -0.131893
# Airline_Jet Airways Business                                                     -0.004166
# Airline_Multiple carriers                                                        -0.062399
# Airline_Multiple carriers Premium economy                                        -0.006134
# Airline_SpiceJet                                                                  0.610243
# Airline_Trujet                                                                   -0.001700
# Airline_Vistara                                                                  -0.038076
# Airline_Vistara Premium economy                                                  -0.002945
# Source_Banglore                                                                   0.016555
# Source_Chennai                                                                    0.143869
# Source_Delhi                                                                     -0.133195
# Source_Kolkata                                                                    0.032200
# Source_Mumbai                                                                     0.073647
# Destination_Banglore                                                              0.032200
# Destination_Cochin                                                               -0.133195
# Destination_Delhi                                                                 0.044368
# Destination_Hyderabad                                                             0.073647
# Destination_Kolkata                                                               0.143869
# Destination_New Delhi                                                            -0.027088
# Additional_Info_1 Long layover                                                   -0.007418
# Additional_Info_1 Short layover                                                  -0.001700
# Additional_Info_2 Long layover                                                   -0.001700
# Additional_Info_Business class                                                   -0.003401
# Additional_Info_Change airports                                                  -0.004500
# Additional_Info_In-flight meal not included                                      -0.083877
# Additional_Info_No Info                                                          -0.002945
# Additional_Info_No check-in baggage included                                      1.000000
# Additional_Info_No info                                                          -0.331985
# Additional_Info_Red-eye flight                                                   -0.001700
#
#                                               Additional_Info_No info  \
# Total_Stops                                                 -0.021140
# Price                                                        0.022247
# Day                                                         -0.036362
# Month                                                       -0.065403
# Dep_Hours                                                   -0.048484
# Dep_Minutes                                                 -0.029510
# Arrival_Hour                                                 0.050682
# Arrival_Minute                                               0.043024
# Duration_Hour                                               -0.103162
# Duration_Minute                                              0.035176
# Route_1                                                           NaN
# Route_2                                                           NaN
# Route_3                                                     -0.076307
# Route_4                                                      0.055531
# Route_5                                                      0.031354
# Route_6                                                     -0.018279
# Length_of_Route                                             -0.021140
# Airline_Air Asia                                             0.091542
# Airline_Air India                                            0.225210
# Airline_GoAir                                                0.071993
# Airline_IndiGo                                               0.256472
# Airline_Jet Airways                                         -0.498261
# Airline_Jet Airways Business                                -0.016118
# Airline_Multiple carriers                                    0.119027
# Airline_Multiple carriers Premium economy                    0.018478
# Airline_SpiceJet                                            -0.120868
# Airline_Trujet                                               0.005122
# Airline_Vistara                                              0.114694
# Airline_Vistara Premium economy                              0.008872
# Source_Banglore                                              0.014487
# Source_Chennai                                               0.028555
# Source_Delhi                                                 0.031059
# Source_Kolkata                                              -0.059046
# Source_Mumbai                                               -0.001325
# Destination_Banglore                                        -0.059046
# Destination_Cochin                                           0.031059
# Destination_Delhi                                            0.022335
# Destination_Hyderabad                                       -0.001325
# Destination_Kolkata                                          0.028555
# Destination_New Delhi                                       -0.004822
# Additional_Info_1 Long layover                              -0.079745
# Additional_Info_1 Short layover                             -0.018279
# Additional_Info_2 Long layover                              -0.018279
# Additional_Info_Business class                              -0.036564
# Additional_Info_Change airports                             -0.048376
# Additional_Info_In-flight meal not included                 -0.901690
# Additional_Info_No Info                                     -0.031664
# Additional_Info_No check-in baggage included                -0.331985
# Additional_Info_No info                                      1.000000
# Additional_Info_Red-eye flight                              -0.018279
#
#                                               Additional_Info_Red-eye flight
# Total_Stops                                                        -0.011811
# Price                                                               0.003747
# Day                                                                -0.014275
# Month                                                              -0.014199
# Dep_Hours                                                           0.017689
# Dep_Minutes                                                         0.000305
# Arrival_Hour                                                       -0.016010
# Arrival_Minute                                                     -0.008612
# Duration_Hour                                                      -0.008635
# Duration_Minute                                                     0.009521
# Route_1                                                                  NaN
# Route_2                                                                  NaN
# Route_3                                                            -0.013887
# Route_4                                                            -0.004010
# Route_5                                                            -0.000636
# Route_6                                                            -0.000094
# Length_of_Route                                                    -0.011811
# Airline_Air Asia                                                    0.055149
# Airline_Air India                                                  -0.004284
# Airline_GoAir                                                      -0.001316
# Airline_IndiGo                                                     -0.004720
# Airline_Jet Airways                                                -0.007262
# Airline_Jet Airways Business                                       -0.000229
# Airline_Multiple carriers                                          -0.003436
# Airline_Multiple carriers Premium economy                          -0.000338
# Airline_SpiceJet                                                   -0.002786
# Airline_Trujet                                                     -0.000094
# Airline_Vistara                                                    -0.002097
# Airline_Vistara Premium economy                                    -0.000162
# Source_Banglore                                                     0.019015
# Source_Chennai                                                     -0.001861
# Source_Delhi                                                       -0.008313
# Source_Kolkata                                                     -0.005866
# Source_Mumbai                                                      -0.002556
# Destination_Banglore                                               -0.005866
# Destination_Cochin                                                 -0.008313
# Destination_Delhi                                                  -0.003546
# Destination_Hyderabad                                              -0.002556
# Destination_Kolkata                                                -0.001861
# Destination_New Delhi                                               0.031296
# Additional_Info_1 Long layover                                     -0.000408
# Additional_Info_1 Short layover                                    -0.000094
# Additional_Info_2 Long layover                                     -0.000094
# Additional_Info_Business class                                     -0.000187
# Additional_Info_Change airports                                    -0.000248
# Additional_Info_In-flight meal not included                        -0.004618
# Additional_Info_No Info                                            -0.000162
# Additional_Info_No check-in baggage included                       -0.001700
# Additional_Info_No info                                            -0.018279
# Additional_Info_Red-eye flight                                      1.000000
#
# [50 rows x 50 columns]

# %%
# plt.figure(figsize=(12, 8))
# sns.heatmap(df.corr(numeric_only=True), annot=True)
# plt.show()

# %%
s = df.Length_of_Route.value_counts()
plt.figure(figsize=(14, 10))
plt.pie(s.values, labels=s.index, autopct="%.2f%%")
plt.show()

# %%
sns.countplot(x="Duration_Hour", data=df)
# Out:
# <Axes: xlabel='Duration_Hour', ylabel='count'>

# %%
sns.histplot(df["Dep_Hours"], kde=True)
# Out:
# <Axes: xlabel='Dep_Hours', ylabel='Count'>

# %%
sns.histplot(df["Dep_Minutes"])
# Out:
# <Axes: xlabel='Dep_Minutes', ylabel='Count'>

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
sns.boxplot(df["Day"])

plt.subplot(2, 2, 2)
sns.boxplot(df["Arrival_Hour"])

plt.subplot(2, 2, 3)
sns.boxplot(df["Duration_Minute"])

plt.subplot(2, 2, 4)
sns.boxplot(df["Total_Stops"])
sns.stripplot(df["Total_Stops"])
# Out:
# <Axes: ylabel='Total_Stops'>

# %%
df.head(2)
# Out:
#    Total_Stops  Price  Day  Month  Dep_Hours  Dep_Minutes  Arrival_Hour  \
# 0            0   3897   24      3         22           20             1
# 1            2   7662    1      5          5           50            13
#
#    Arrival_Minute  Duration_Hour  Duration_Minute  ...  \
# 0              10              2               50  ...
# 1              15              7               25  ...
#
#    Additional_Info_1 Long layover  Additional_Info_1 Short layover  \
# 0                               0                                0
# 1                               0                                0
#
#    Additional_Info_2 Long layover  Additional_Info_Business class  \
# 0                               0                               0
# 1                               0                               0
#
#    Additional_Info_Change airports  \
# 0                                0
# 1                                0
#
#    Additional_Info_In-flight meal not included  Additional_Info_No Info  \
# 0                                            0                        0
# 1                                            0                        0
#
#    Additional_Info_No check-in baggage included  Additional_Info_No info  \
# 0                                             0                        1
# 1                                             0                        1
#
#    Additional_Info_Red-eye flight
# 0                               0
# 1                               0
#
# [2 rows x 50 columns]

# %%
# Is there any relation between 
sns.countplot(x="Total_Stops", hue="Length_of_Route", data=df)
plt.show()

# %%
sns.boxplot(y="Length_of_Route", hue="Total_Stops", data=df)
# Out:
# <Axes: ylabel='Length_of_Route'>

# %%
sns.boxplot(df["Duration_Hour"])
sns.stripplot(df["Duration_Hour"])
plt.show()

# %% [markdown]
# # Train Test Split

# %%
# Feature selection
y = df["Price"]
df.drop("Price", axis=1, inplace=True)

# %%
# splitting the DataFrame in the train test split
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2, random_state=0)
# X_train
# X_test
# y_train
# y_test
len(y_test)
# Out:
# 2137

# %%
X_train_data = X_train[["Day", "Length_of_Route", "Total_Stops", "Duration_Hour", "Duration_Minute", "Route_3"]].values
X_test_data = X_test[["Day", "Length_of_Route", "Total_Stops", "Duration_Hour", "Duration_Minute", "Route_3"]].values

# X_train_data
# X_test_data

# %% [markdown]
# # Model Linear Regression

# %%
model = LinearRegression()
model.fit(X_train_data, y_train)
# Out:
# LinearRegression()

# %%
# coef_
m = model.coef_
m
# Out:
# array([-7.32083509e+01,  8.68791274e+15, -8.68791274e+15,  6.40000000e+01,
#        -1.00000000e+00,  3.05440625e+03])

# %%
# intercept_
c = model.intercept_
c
# Out:
# -1.7375825477857938e+16

# %%
# y_predicted value
y_pred = model.predict(X_test_data)
y_pred[:5], len(y_pred)
# Out:
# (array([10318.,  9704.,  4004., 10712.,  5890.]), 2137)

# %%
X_test_data[0]
# Out:
# array([15,  3,  1,  8, 30,  1], dtype=int64)

# %%
price = c + m[0] * df["Day"] + m[1] * df["Length_of_Route"] + m[2] * df["Total_Stops"] + m[3] * df["Duration_Hour"] + m[4] * df["Duration_Minute"] + m[5] * df["Route_3"]
price
# Out:
# 0         4192.00000
# 1        13291.40625
# 2        13500.40625
# 3        10352.40625
# 4        11072.40625
#             ...
# 10677     5312.00000
# 10678     3989.00000
# 10679     4088.00000
# 10680     5886.00000
# 10681    12776.40625
# Length: 10682, dtype: float64

# %%
df.head(2)
# Out:
#    Total_Stops  Day  Month  Dep_Hours  Dep_Minutes  Arrival_Hour  \
# 0            0   24      3         22           20             1
# 1            2    1      5          5           50            13
#
#    Arrival_Minute  Duration_Hour  Duration_Minute  Route_1  ...  \
# 0              10              2               50        1  ...
# 1              15              7               25        1  ...
#
#    Additional_Info_1 Long layover  Additional_Info_1 Short layover  \
# 0                               0                                0
# 1                               0                                0
#
#    Additional_Info_2 Long layover  Additional_Info_Business class  \
# 0                               0                               0
# 1                               0                               0
#
#    Additional_Info_Change airports  \
# 0                                0
# 1                                0
#
#    Additional_Info_In-flight meal not included  Additional_Info_No Info  \
# 0                                            0                        0
# 1                                            0                        0
#
#    Additional_Info_No check-in baggage included  Additional_Info_No info  \
# 0                                             0                        1
# 1                                             0                        1
#
#    Additional_Info_Red-eye flight
# 0                               0
# 1                               0
#
# [2 rows x 49 columns]

# %%
sns.regplot(x="Length_of_Route", y=y, data=df, color="Red")
sns.regplot(x="Length_of_Route", y=price, data=df, color="Blue")
# Out:
# <Axes: xlabel='Length_of_Route'>

# %%
ax1 = sns.distplot(y_test, hist=False, color="r", label="Actual value")
sns.distplot(y_pred, hist=False, color="b", label="fitted values", ax=ax1)
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_16312\3582859058.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(y_test, hist=False, color="r", label="Actual value")
# C:\Users\Hp\AppData\Local\Temp\ipykernel_16312\3582859058.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred, hist=False, color="b", label="fitted values", ax=ax1)

# %%
# Mean absolute error
mse = mean_squared_error(y_true=y_test, y_pred=y_pred)
mse
# Out:
# 13661084.84043051

# %%
# Mean absolute error
mae = mean_absolute_error(y_true=y_test, y_pred=y_pred)
mae
# Out:
# 2460.004679457183

# %%
# r2_score
r2 = r2_score(y_true=y_test, y_pred=y_pred)
r2
# Out:
# 0.4177648652068089

# %%
X_train_data = X_train.values
X_test_data = X_test.values
model = LinearRegression()
model.fit(X_train_data, y_train)
m = model.coef_
c = model.intercept_
y_pred = model.predict(X_test_data)
price = c + m[0] * df["Day"] + m[1] * df["Length_of_Route"]
mse = mean_squared_error(y_true=y_test, y_pred=y_pred)
mae = mean_absolute_error(y_true=y_test, y_pred=y_pred)
r2 = r2_score(y_true=y_test, y_pred=y_pred)

# %%
mse, mae, r2, m, c
# Out:
# (1.1326890890381412e+21,
#  728038209.4607748,
#  -48275184009039.68,
#  array([ 6.22325520e+12, -6.11046143e+01, -3.59316874e+02,  1.85908045e+01,
#         -2.19883012e+00, -1.56167079e+01,  3.08911926e+00,  1.27675491e+01,
#          1.95557657e+00, -9.76562500e-04, -4.88281250e-04, -1.55581380e+12,
#         -1.55581380e+12, -1.55581380e+12,  2.44140625e-04, -4.66744140e+12,
#         -4.98490732e+03, -3.20613345e+03, -4.97957199e+03, -4.79395265e+03,
#          1.00357333e+03,  3.71152236e+04, -1.35996514e+03, -1.19916270e+03,
#         -5.13047179e+03, -7.89057398e+03, -2.89446513e+03, -1.67958804e+03,
#          3.33024152e+02,  2.07227280e+02,  9.86157406e+01,  2.67184915e+01,
#         -6.65591396e+02,  2.67185220e+01,  9.86153743e+01, -8.50057560e+02,
#         -6.65591251e+02,  2.07227168e+02,  1.18308554e+03,  4.06678469e+03,
#          8.11536549e+03,  7.80337615e+03,  9.29946570e+03, -2.44517742e+03,
#         -8.40347541e+03, -7.24962045e+03, -5.05112522e+03, -4.84937158e+03,
#         -1.28621987e+03]),
#  9334882810122.166)

# %%
y_pred
# Out:
# array([13214.56054688,  7115.1640625 ,  2895.10546875, ...,
#        10953.5234375 ,  9948.23828125,  4213.5390625 ])

# %%
X_train_data = X_train[["Duration_Hour"]].values
X_test_data = X_test[["Duration_Hour"]].values
model = LinearRegression()
model.fit(X_train_data, y_train)
m = model.coef_
c = model.intercept_
y_pred = model.predict(X_test_data)
price = c + m[0] * df["Duration_Hour"]
mse = mean_squared_error(y_true=y_test, y_pred=y_pred)
mae = mean_absolute_error(y_true=y_test, y_pred=y_pred)
r2 = r2_score(y_true=y_test, y_pred=y_pred)

# %%
mse, mae, r2
# Out:
# (18987018.30485045, 3128.4556943992443, 0.1907736983429048)

# %%
price
# Out:
# 0         7197.865411
# 1         8822.536424
# 2        12721.746856
# 3         8172.668019
# 4         7847.733816
#              ...
# 10677     7197.865411
# 10678     7197.865411
# 10679     7522.799614
# 10680     7197.865411
# 10681     9147.470627
# Name: Duration_Hour, Length: 10682, dtype: float64

# %%
X_train_data = X_train[["Total_Stops"]].values
X_test_data = X_test[["Total_Stops"]].values
model = LinearRegression()
model.fit(X_train_data, y_train)
m = model.coef_
c = model.intercept_
y_pred = model.predict(X_test_data)
price = c + m[0] * df["Total_Stops"]
mse = mean_squared_error(y_true=y_test, y_pred=y_pred)
mae = mean_absolute_error(y_true=y_test, y_pred=y_pred)
r2 = r2_score(y_true=y_test, y_pred=y_pred)

# %%
mse, mae, r2
# Out:
# (15172167.651184388, 2649.876198786191, 0.35336254911847464)

# %%
sns.heatmap(df_X.corr(), annot=True)
# Out:
# <Axes: >

# %%
X_train_data = X_train[["Length_of_Route"]].values
X_test_data = X_test[["Length_of_Route"]].values
model = LinearRegression()
model.fit(X_train_data, y_train)
m = model.coef_
c = model.intercept_
y_pred = model.predict(X_test_data)
price = c + m[0] * df["Length_of_Route"]
mse = mean_squared_error(y_true=y_test, y_pred=y_pred)
mae = mean_absolute_error(y_true=y_test, y_pred=y_pred)
r2 = r2_score(y_true=y_test, y_pred=y_pred)
mse, mae, r2
# Out:
# (15172167.651184388, 2649.876198786191, 0.35336254911847464)

# %%
X_train_data = X_train[["Length_of_Route", "Duration_Hour", "Route_3"]].values
X_test_data = X_test[["Length_of_Route", "Duration_Hour", "Route_3"]].values
model = LinearRegression()
model.fit(X_train_data, y_train)
m = model.coef_
c = model.intercept_
y_pred = model.predict(X_test_data)
price = c + m[0] * df["Length_of_Route"] + m[1] * df["Duration_Hour"] + m[2] * df["Route_3"]
mse = mean_squared_error(y_true=y_test, y_pred=y_pred)
mae = mean_absolute_error(y_true=y_test, y_pred=y_pred)
r2 = r2_score(y_true=y_test, y_pred=y_pred)
mse, mae, r2
# Out:
# (14279655.97589183, 2477.1889951315447, 0.3914013770474637)

# %%
ax1 = sns.distplot(y_test, hist=False, color="r", label="Actual value")
sns.distplot(y_pred, hist=False, color="b", label="fitted values", ax=ax1)
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_16312\3582859058.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(y_test, hist=False, color="r", label="Actual value")
# C:\Users\Hp\AppData\Local\Temp\ipykernel_16312\3582859058.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred, hist=False, color="b", label="fitted values", ax=ax1)

# %%
y_test
# Out:
# 10506    14781
# 7705      5636
# 7700      3597
# 1437     16757
# 8884      4804
#          ...
# 6391      3943
# 9272      4804
# 6199      8971
# 10036     9663
# 8970      3873
# Name: Price, Length: 2137, dtype: int64

# %%
y_pred
# Out:
# array([10432.63237629, 10242.98739413,  5024.57225209, ...,
#        11860.47050822, 10685.49235251,  5024.57225209])
